# %%
import mysql.connector
from DrissionPage import ChromiumPage
from mysql.connector import Error

# 連接到 MySQL 資料庫
def create_connection():
    try:
        connection = mysql.connector.connect(
            host='127.0.0.1',
            database='kol_1017',
            user='root',
            password='123456789',
            port=3306
        )
        if connection.is_connected():
            print("Connected to MySQL database.")
            return connection
    except Error as e:
        print(f"Error while connecting to MySQL: {e}")
    return None

# 從資料庫中獲取 URL 列表
def fetch_urls(connection):
    cursor = connection.cursor()
    cursor.execute("SELECT kol_link FROM kol_radar_link")
    urls = cursor.fetchall()
    cursor.close()
    return [url[0] for url in urls]

# 爬取資料
import time
import re

def scrape_data_with_retry(url, retries=2, delay=5):
    for attempt in range(retries + 1):
        try:
            # 嘗試爬取
            print(f"嘗試第 {attempt + 1} 次爬取...")
            return scrape_data(url)
        except Exception as e:
            print(f"錯誤: {e}")
            if attempt < retries:
                print(f"等待 {delay} 秒後重新嘗試...")
                time.sleep(delay)
            else:
                print("已達到最大嘗試次數，跳過此URL。")
                return {"error": f"Failed to scrape {url} after {retries + 1} attempts."}

def scrape_data(url):
    page = ChromiumPage()
    page.get(url)
    page.wait(10)

    try:
        # 取得KOL基本數據
        kol_name = page.ele('.ant-flex css-var-r4 ant-flex-align-center').html
        kol_name = re.search(r'<span[^>]*>([^<|]+)', kol_name).group(1).strip()
    except Exception:
        kol_name = "未能取得名稱"

    try:
        # 網紅類型
        kol_type = page.ele('.basic-info__CustomizedNamesBlock-sc-e3553b7c-4 hdhFjC').text.replace('網紅類型', '').replace('\n', '').replace(' · ', '、')
    except Exception:
        kol_type = "未能取得類型"

    # try:
    #     # IG數據總攬
    #     kol_data_titles = page.eles('.kol-detail-statistic__Title-sc-97698071-4 hBbmvW')    
    #     kol_data_values = page.eles('.kol-detail-statistic__Value-sc-97698071-8 gHYCoJ')
    #     kol_sex_ratio = page.eles('.audience-analysis__Percentage-sc-8366c75d-2 fHbKYa')[0].text
    #     kol_age_ratio = page.eles('.audience-analysis__Percentage-sc-8366c75d-2 fHbKYa')[1].text
    kol_ig_link = page.ele('.kol-platform-link__SocialLinkText-sc-549f2da9-1 cspYLa').text
    kol_ig_id = kol_ig_link.replace('https://www.instagram.com/', '').replace('/', '')
    if "?" in kol_ig_id:
        kol_ig_id = kol_ig_id.split("?")[0]
        
    # except Exception:
    #     kol_data_titles, kol_data_values, kol_sex_ratio, kol_age_ratio = [], [], "未能取得性別比率", "未能取得年齡比率"
    #     kol_ig_link, kol_ig_id = "未能取得IG連結", "未能取得帳號名稱"

    # 建構KOL數據字典
    new_kol_data_dict = {}
    new_kol_data_dict['kol_link'] = url
    new_kol_data_dict['kol_name'] = kol_name
    new_kol_data_dict['kol_ig_id'] = kol_ig_id
    new_kol_data_dict['kol_ig_link'] = kol_ig_link
    new_kol_data_dict['type'] = kol_type

    # # 新增KOL其他數據
    # for i in range(len(kol_data_titles)):
    #     try:
    #         new_kol_data_dict[kol_data_titles[i].text] = kol_data_values[i].text
    #         if kol_data_titles[i].text == '女性':
    #             kol_data_titles[i].text = 0
    #         elif kol_data_titles[i].text == '男性':
    #             kol_data_titles[i].text = 1
            
    #     except Exception:
    #         continue

    print(new_kol_data_dict)
    return new_kol_data_dict

# %%
# 主函數
def main():
    connection = create_connection()
    if connection:
        try:
            urls = fetch_urls(connection)
            for url in urls[1:3]:
                print(url)
                data = scrape_data(url)                    
        finally:
            connection.close()
            print("Database connection closed.")
    
# 執行主函數
main()
# Out:
# Connected to MySQL database.
# https://app.kolradar.com//kol/2b5601d6-7464-44c1-9ec0-69021e59d0c2?from=socialAccountRanking
# {'kol_link': 'https://app.kolradar.com//kol/2b5601d6-7464-44c1-9ec0-69021e59d0c2?from=socialAccountRanking', '名稱': '⚡️派瑞 Perry Green', '帳號名稱': 'perrygreeeen', '社群連結': 'https://www.instagram.com/perrygreeeen?igsh=N3VpbzE5MHB2bzFi', '類型': '台灣旅遊、藝術與娛樂', '性別': '男', '主要語言': '繁體中文', '追蹤數': '76,835', '互動率': '20.7%', '觀看率': '667%', '漲粉率': '35.7%', '受眾主要性別': '女性', '主要性別占比%': '76%', '受眾主要年齡': '25-34 歲', '主要年齡層占比%': '76%', '商業合作內容覆蓋比例': '30%', '漲粉數': '28,830', '成長趨勢': '高潛力', '貼文預估觸及數': '3.8萬-4.5萬', '影音預估觸及數': '348.9萬-1.1億', '受眾主要國家/地區': 'Taiwan', '圖文合作費用預估': '$500 - $1,000', '影音合作費用預估': '$1,200 - $12,000', '圖文口碑價值': '$139,599', '影音口碑價值': '$139,599', '按讚評論比': '5 : 100', '平均互動數': '15,868', '平均按讚數': '15,767', '平均留言數': '101', 'Reels 互動率': '18%', 'Reels 平均互動數': '1,235', 'Reels 平均按讚數': '1,213', 'Reels 平均留言數': '22', 'Reels 觀看率': '667%', 'Reels 平均觀看數': '512,450', '期間內容數': '30', '發文頻率': '10 篇'}
# https://app.kolradar.com//kol/bb669de8-df1b-44ae-8560-bd50b6906c80?from=socialAccountRanking
# {'kol_link': 'https://app.kolradar.com//kol/bb669de8-df1b-44ae-8560-bd50b6906c80?from=socialAccountRanking', '名稱': '華華ゆか', '帳號名稱': 'araiyuka', '社群連結': 'https://www.instagram.com/araiyuka/', '類型': '健身、彩妝', '性別': '女', '主要語言': '繁體中文', '追蹤數': '35,155', '互動率': '5.04%', '觀看率': '514%', '漲粉率': '35.7%', '受眾主要性別': '女性', '主要性別占比%': '76%', '受眾主要年齡': '25-34 歲', '主要年齡層占比%': '76%', '商業合作內容覆蓋比例': '30%', '漲粉數': '28,830', '成長趨勢': '高潛力', '貼文預估觸及數': '3.8萬-4.5萬', '影音預估觸及數': '348.9萬-1.1億', '受眾主要國家/地區': 'Taiwan', '圖文合作費用預估': '$500 - $1,000', '影音合作費用預估': '$1,200 - $12,000', '圖文口碑價值': '$139,599', '影音口碑價值': '$139,599', '按讚評論比': '5 : 100', '平均互動數': '1,773', '平均按讚數': '853', '平均留言數': '920', 'Reels 互動率': '18%', 'Reels 平均互動數': '1,235', 'Reels 平均按讚數': '1,213', 'Reels 平均留言數': '22', 'Reels 觀看率': '514%', 'Reels 平均觀看數': '180,691', '期間內容數': '31', '發文頻率': '10 篇'}
# Database connection closed.

# %% [markdown]
# ## 爬取網紅於KOLR上的資訊

# %%
import mysql.connector
from DrissionPage import ChromiumPage
from mysql.connector import Error
import time
import re

# 建立資料庫連線
def create_connection():
    try:
        connection = mysql.connector.connect(
            host='127.0.0.1',
            database='kol_1017',
            user='root',
            password='123456789',
            port=3306
        )
        if connection.is_connected():
            print("Connected to MySQL database.")
            return connection
    except Error as e:
        print(f"Error while connecting to MySQL: {e}")
    return None

# 從資料庫中獲取 URL 列表
def fetch_urls(connection):
    try:
        cursor = connection.cursor()
        cursor.execute("SELECT kol_link FROM kol_radar_link")
        urls = cursor.fetchall()
        cursor.close()
        return [url[0] for url in urls]
    except Error as e:
        print(f"Error while fetching URLs: {e}")
        return []

# 插入數據到資料庫
def insert_kol_data(connection, data):
    try:
        cursor = connection.cursor()
        insert_query = """
            INSERT INTO kol_radar_info (kol_link, kol_name, kol_ig_id, kol_ig_link, type)
            VALUES (%s, %s, %s, %s, %s)
        """
        cursor.execute(insert_query, (
            data['kol_link'],
            data['kol_name'],
            data['kol_ig_id'],
            data['kol_ig_link'],
            data['type']
        ))
        connection.commit()
        print(f"成功插入資料: {data['kol_name']}")
    except Error as e:
        print(f"Error while inserting data: {e}")

# 爬取資料（支援重試機制）
def scrape_data_with_retry(url, retries=2, delay=5):
    for attempt in range(retries + 1):
        try:
            print(f"嘗試第 {attempt + 1} 次爬取...")
            return scrape_data(url)
        except Exception as e:
            print(f"錯誤: {e}")
            if attempt < retries:
                print(f"等待 {delay} 秒後重新嘗試...")
                time.sleep(delay)
            else:
                print("已達到最大嘗試次數，跳過此URL。")
                return None

# 爬取資料
def scrape_data(url):
    page = ChromiumPage()
    page.get(url)
    page.wait(10)

    try:
        # 取得KOL基本數據
        kol_name = page.ele('.ant-flex css-var-r4 ant-flex-align-center').html
        kol_name = re.search(r'<span[^>]*>([^<|]+)', kol_name).group(1).strip()
    except Exception:
        kol_name = "未能取得名稱"

    try:
        # 網紅類型
        kol_type = page.ele('.basic-info__CustomizedNamesBlock-sc-e3553b7c-4 hdhFjC').text.replace('網紅類型', '').replace('\n', '').replace(' · ', '、')
    except Exception:
        kol_type = "未能取得類型"

    try:
        # Instagram 資料
        kol_ig_link = page.ele('.kol-platform-link__SocialLinkText-sc-549f2da9-1 cspYLa').text
        kol_ig_id = kol_ig_link.replace('https://www.instagram.com/', '').replace('/', '')
        if "?" in kol_ig_id:
            kol_ig_id = kol_ig_id.split("?")[0]
    except Exception:
        kol_ig_link, kol_ig_id = "未能取得鏈接", "未能取得帳號"

    # 建構KOL數據字典
    new_kol_data_dict = {
        'kol_link': url,
        'kol_name': kol_name,
        'kol_ig_id': kol_ig_id,
        'kol_ig_link': kol_ig_link,
        'type': kol_type
    }
    print(new_kol_data_dict)
    return new_kol_data_dict

# 主函數
def main():
    connection = create_connection()
    if connection:
        try:
            urls = fetch_urls(connection)
            for url in urls[11:]:
                print(f"處理 URL: {url}")
                data = scrape_data_with_retry(url)
                if data:  # 確保數據有效
                    insert_kol_data(connection, data)
        finally:
            connection.close()
            print("Database connection closed.")

# %%
# 執行主函數
if __name__ == "__main__":
    main()
# Out:
# Connected to MySQL database.
# 處理 URL: https://app.kolradar.com//kol/0e63845e-9a3c-464b-8930-a175d06a7752?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0e63845e-9a3c-464b-8930-a175d06a7752?from=socialAccountRanking', 'kol_name': '吳玳慈 阿布', 'kol_ig_id': 'dianna__914', 'kol_ig_link': 'https://www.instagram.com/dianna__914/', 'type': '台灣旅遊、職場、奢侈品'}
# 成功插入資料: 吳玳慈 阿布
# 處理 URL: https://app.kolradar.com//kol/6f35c360-bb66-4279-9bd0-e468e8e61d92?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6f35c360-bb66-4279-9bd0-e468e8e61d92?from=socialAccountRanking', 'kol_name': '赤鬼伯伯akaoni', 'kol_ig_id': 'akaonikou', 'kol_ig_link': 'https://www.instagram.com/akaonikou/', 'type': '電腦遊戲、日常話題、遊戲'}
# 成功插入資料: 赤鬼伯伯akaoni
# 處理 URL: https://app.kolradar.com//kol/e32c4478-83da-446d-9b50-00d7b308f529?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/e32c4478-83da-446d-9b50-00d7b308f529?from=socialAccountRanking', 'kol_name': '柯佳嬿', 'kol_ig_id': 'alicekochiayen', 'kol_ig_link': 'https://www.instagram.com/alicekochiayen/', 'type': '電影、藝術與娛樂、美妝時尚、旅遊、保養'}
# 成功插入資料: 柯佳嬿
# 處理 URL: https://app.kolradar.com//kol/a0d15477-560f-46f4-985a-bf8bc023a370?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a0d15477-560f-46f4-985a-bf8bc023a370?from=socialAccountRanking', 'kol_name': 'Allen Tsai', 'kol_ig_id': 'imallentsai', 'kol_ig_link': 'https://www.instagram.com/imallentsai/', 'type': '機車、電影、藝術與娛樂、日常話題、交通工具'}
# 成功插入資料: Allen Tsai
# 處理 URL: https://app.kolradar.com//kol/767cd209-9eb1-437c-b0d3-0cc502e21f68?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/767cd209-9eb1-437c-b0d3-0cc502e21f68?from=socialAccountRanking', 'kol_name': 'AMBER แอมเบอร์', 'kol_ig_id': 'amberleeee35', 'kol_ig_link': 'https://www.instagram.com/amberleeee35/', 'type': '東南亞旅遊、美食、旅遊、飲料'}
# 成功插入資料: AMBER แอมเบอร์
# 處理 URL: https://app.kolradar.com//kol/ead735e9-c16e-46c8-bf39-eda349a26dff?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/ead735e9-c16e-46c8-bf39-eda349a26dff?from=socialAccountRanking', 'kol_name': 'Amber.L 日文學習｜培養你的日文語感', 'kol_ig_id': 'amberlspace', 'kol_ig_link': 'https://www.instagram.com/amberlspace/', 'type': '語言學習、教育與學習、家庭、旅遊'}
# 成功插入資料: Amber.L 日文學習｜培養你的日文語感
# 處理 URL: https://app.kolradar.com//kol/00d595a1-45b8-4eff-97dc-1169faadc2cc?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/00d595a1-45b8-4eff-97dc-1169faadc2cc?from=socialAccountRanking', 'kol_name': '꒰ Amy欸米', 'kol_ig_id': 'amyy.amys', 'kol_ig_link': 'https://www.instagram.com/amyy.amys/', 'type': '升學、美食、旅遊'}
# 成功插入資料: ꒰ Amy欸米
# 處理 URL: https://app.kolradar.com//kol/ebedef80-3799-4cd1-8bb9-27ae217712b8?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/ebedef80-3799-4cd1-8bb9-27ae217712b8?from=socialAccountRanking', 'kol_name': 'AnDy Wu', 'kol_ig_id': 'adwmusicland', 'kol_ig_link': 'https://www.instagram.com/adwmusicland/', 'type': '舞蹈、藝術與娛樂、日常話題'}
# 成功插入資料: AnDy Wu
# 處理 URL: https://app.kolradar.com//kol/4cfe4a54-227f-47af-bbd0-83afe6adc249?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/4cfe4a54-227f-47af-bbd0-83afe6adc249?from=socialAccountRanking', 'kol_name': 'Andy老師', 'kol_ig_id': 'andy1994x', 'kol_ig_link': 'https://www.instagram.com/andy1994x/', 'type': '健身、藝術與娛樂、日常話題、教育與學習、家庭、運動、旅遊'}
# 成功插入資料: Andy老師
# 處理 URL: https://app.kolradar.com//kol/8fd58692-20b3-402d-ba3e-a9c0584154e1?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/8fd58692-20b3-402d-ba3e-a9c0584154e1?from=socialAccountRanking', 'kol_name': '廖安琪 🌷Megan安琪兒', 'kol_ig_id': 'meganbyangel', 'kol_ig_link': 'https://www.instagram.com/meganbyangel/', 'type': '香水、投資、財經'}
# 成功插入資料: 廖安琪 🌷Megan安琪兒
# 處理 URL: https://app.kolradar.com//kol/cdcf02da-c34a-404f-998e-dc3a8c06ab25?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/cdcf02da-c34a-404f-998e-dc3a8c06ab25?from=socialAccountRanking', 'kol_name': 'Anita🎀', 'kol_ig_id': 'anitatsai0213', 'kol_ig_link': 'https://www.instagram.com/anitatsai0213/', 'type': '舞蹈'}
# 成功插入資料: Anita🎀
# 處理 URL: https://app.kolradar.com//kol/9642f603-d013-4d5f-92c9-0ec1905d9727?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/9642f603-d013-4d5f-92c9-0ec1905d9727?from=socialAccountRanking', 'kol_name': '廖小安', 'kol_ig_id': 'ann5103', 'kol_ig_link': 'https://www.instagram.com/ann5103/', 'type': '高爾夫、命理占卜、遊戲'}
# 成功插入資料: 廖小安
# 處理 URL: https://app.kolradar.com//kol/765ffa3f-972a-47c2-bcf9-9c5c518d4bc9?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/765ffa3f-972a-47c2-bcf9-9c5c518d4bc9?from=socialAccountRanking', 'kol_name': 'Anna呱 🐸', 'kol_ig_id': 'bbnnbb_anna', 'kol_ig_link': 'https://www.instagram.com/bbnnbb_anna/', 'type': '醫美、美妝時尚、日常話題、家庭、穿搭'}
# 成功插入資料: Anna呱 🐸
# 處理 URL: https://app.kolradar.com//kol/dcb123e2-275d-48a5-b0f6-79c8dce8cd76?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/dcb123e2-275d-48a5-b0f6-79c8dce8cd76?from=socialAccountRanking', 'kol_name': 'A n n i', 'kol_ig_id': 'anniekaly', 'kol_ig_link': 'https://www.instagram.com/anniekaly/', 'type': '甜點、美食'}
# 成功插入資料: A n n i
# 處理 URL: https://app.kolradar.com//kol/45290a3c-f997-481a-805d-0eec53c7f2f7?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/45290a3c-f997-481a-805d-0eec53c7f2f7?from=socialAccountRanking', 'kol_name': 'Ariel Lin 林依晨', 'kol_ig_id': 'linyichen.ariellin', 'kol_ig_link': 'https://www.instagram.com/linyichen.ariellin/', 'type': '電影、藝術與娛樂、日常話題、旅遊'}
# 成功插入資料: Ariel Lin 林依晨
# 處理 URL: https://app.kolradar.com//kol/0b14bee6-7326-4b75-8306-c5673b859137?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0b14bee6-7326-4b75-8306-c5673b859137?from=socialAccountRanking', 'kol_name': 'A冷', 'kol_ig_id': 'alansmart123', 'kol_ig_link': 'https://www.instagram.com/alansmart123/', 'type': '手機遊戲、藝術與娛樂、日常話題、教育與學習、遊戲、飲料'}
# 成功插入資料: A冷
# 處理 URL: https://app.kolradar.com//kol/ae0838c2-5484-4288-b219-3557c73dd589?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/ae0838c2-5484-4288-b219-3557c73dd589?from=socialAccountRanking', 'kol_name': 'BetweenGos｜優勢探索 X 求職實戰 X 職涯諮詢', 'kol_ig_id': 'betweengos', 'kol_ig_link': 'https://www.instagram.com/betweengos/', 'type': '職場、日常話題、教育與學習、財經、運動'}
# 成功插入資料: BetweenGos｜優勢探索 X 求職實戰 X 職涯諮詢
# 處理 URL: https://app.kolradar.com//kol/fd0b3b5c-6af4-450c-9622-473e71f58dab?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/fd0b3b5c-6af4-450c-9622-473e71f58dab?from=socialAccountRanking', 'kol_name': '小比', 'kol_ig_id': 'bi.daily.learning', 'kol_ig_link': 'https://www.instagram.com/bi.daily.learning/', 'type': '升學、教育與學習'}
# 成功插入資料: 小比
# 處理 URL: https://app.kolradar.com//kol/7d0387a9-d58e-4fff-9426-028e1a5190b7?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/7d0387a9-d58e-4fff-9426-028e1a5190b7?from=socialAccountRanking', 'kol_name': 'Blue王', 'kol_ig_id': 'bluee_wong', 'kol_ig_link': 'https://www.instagram.com/bluee_wong/', 'type': '3C家電、手機遊戲、日常話題、遊戲'}
# 成功插入資料: Blue王
# 處理 URL: https://app.kolradar.com//kol/8cdb8864-f671-4551-a5d4-baa21f1fc3e1?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/8cdb8864-f671-4551-a5d4-baa21f1fc3e1?from=socialAccountRanking', 'kol_name': 'Butterfly愷樂🦋', 'kol_ig_id': 'butterfly092288', 'kol_ig_link': 'https://www.instagram.com/butterfly092288', 'type': '命理占卜、節慶'}
# 成功插入資料: Butterfly愷樂🦋
# 處理 URL: https://app.kolradar.com//kol/9957fa57-dde7-43f7-bcfd-08219601d9ae?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/9957fa57-dde7-43f7-bcfd-08219601d9ae?from=socialAccountRanking', 'kol_name': 'cb350.Lin', 'kol_ig_id': 'cb350.lin', 'kol_ig_link': 'https://www.instagram.com/cb350.lin/', 'type': '機車'}
# 成功插入資料: cb350.Lin
# 處理 URL: https://app.kolradar.com//kol/514a9dff-3a38-444a-8cb4-d78b9014f2bd?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/514a9dff-3a38-444a-8cb4-d78b9014f2bd?from=socialAccountRanking', 'kol_name': 'CE CHEN', 'kol_ig_id': 'cce30708', 'kol_ig_link': 'https://www.instagram.com/cce30708', 'type': '婚姻、美食'}
# 成功插入資料: CE CHEN
# 處理 URL: https://app.kolradar.com//kol/5ec5020d-fc3a-44e1-ab1f-dec7d33c238e?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/5ec5020d-fc3a-44e1-ab1f-dec7d33c238e?from=socialAccountRanking', 'kol_name': 'clt___', 'kol_ig_id': 'clt___', 'kol_ig_link': 'https://www.instagram.com/clt___/', 'type': '甜點、旅遊'}
# 成功插入資料: clt___
# 處理 URL: https://app.kolradar.com//kol/53b6b248-4cc5-42ab-a03b-b9c0b8c0fef2?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/53b6b248-4cc5-42ab-a03b-b9c0b8c0fef2?from=socialAccountRanking', 'kol_name': 'cherng', 'kol_ig_id': 'cherngyang', 'kol_ig_link': 'https://www.instagram.com/cherngyang/', 'type': '3C家電、汽車、教育與學習、醫療與健康、飲料'}
# 成功插入資料: cherng
# 處理 URL: https://app.kolradar.com//kol/6b7eaab1-8d35-460c-8aef-19f1e46e8b39?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6b7eaab1-8d35-460c-8aef-19f1e46e8b39?from=socialAccountRanking', 'kol_name': '詢價洽詢LINE客服', 'kol_ig_id': 'chi.boutique', 'kol_ig_link': 'https://www.instagram.com/chi.boutique/', 'type': '奢侈品、促購導購、美妝時尚'}
# 成功插入資料: 詢價洽詢LINE客服
# 處理 URL: https://app.kolradar.com//kol/a75f6a67-2990-41cb-a2cd-3d1de14c2c42?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a75f6a67-2990-41cb-a2cd-3d1de14c2c42?from=socialAccountRanking', 'kol_name': 'Chichi ‘ 薛文娸', 'kol_ig_id': 'chichi_0714', 'kol_ig_link': 'https://www.instagram.com/chichi_0714/', 'type': '親子、家庭'}
# 成功插入資料: Chichi ‘ 薛文娸
# 處理 URL: https://app.kolradar.com//kol/dab3a4e3-a6ec-4540-93a2-0f8c80245d75?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/dab3a4e3-a6ec-4540-93a2-0f8c80245d75?from=socialAccountRanking', 'kol_name': 'chloe shih ✧･ﾟ', 'kol_ig_id': 'chloe.shih', 'kol_ig_link': 'https://www.instagram.com/chloe.shih/', 'type': 'Podcast、藝術與娛樂、日常話題'}
# 成功插入資料: chloe shih ✧･ﾟ
# 處理 URL: https://app.kolradar.com//kol/a503fffc-4b62-4d51-bbf9-5a56bc462050?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a503fffc-4b62-4d51-bbf9-5a56bc462050?from=socialAccountRanking', 'kol_name': 'Cindy Hsiao', 'kol_ig_id': 'cindy881122', 'kol_ig_link': 'https://www.instagram.com/cindy881122/', 'type': '母嬰、網球、教育與學習'}
# 成功插入資料: Cindy Hsiao
# 處理 URL: https://app.kolradar.com//kol/1981099a-7a44-473a-9bbf-1dd110d5d557?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/1981099a-7a44-473a-9bbf-1dd110d5d557?from=socialAccountRanking', 'kol_name': '辛蒂廚房玩料理', 'kol_ig_id': 'cindywu527', 'kol_ig_link': 'https://www.instagram.com/cindywu527/', 'type': '美食、旅遊、食譜'}
# 成功插入資料: 辛蒂廚房玩料理
# 處理 URL: https://app.kolradar.com//kol/0d19f745-b320-4b14-be50-d50068e3d950?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0d19f745-b320-4b14-be50-d50068e3d950?from=socialAccountRanking', 'kol_name': 'Kim', 'kol_ig_id': 'cookim_mama', 'kol_ig_link': 'https://www.instagram.com/cookim_mama/', 'type': '美食、食譜'}
# 成功插入資料: Kim
# 處理 URL: https://app.kolradar.com//kol/548270e7-8e2d-4f60-9e0e-c42a9c18c672?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/548270e7-8e2d-4f60-9e0e-c42a9c18c672?from=socialAccountRanking', 'kol_name': 'Grace的裝修筆記🏡', 'kol_ig_id': 'cosy.home.easy', 'kol_ig_link': 'https://www.instagram.com/cosy.home.easy/', 'type': '室內外設計'}
# 成功插入資料: Grace的裝修筆記🏡
# 處理 URL: https://app.kolradar.com//kol/287de2d8-daeb-4a31-84ea-8908f00b894e?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/287de2d8-daeb-4a31-84ea-8908f00b894e?from=socialAccountRanking', 'kol_name': '崇崇 Daniel', 'kol_ig_id': 'daniel.cwlee', 'kol_ig_link': 'https://www.instagram.com/daniel.cwlee/', 'type': '親子、家庭、旅遊'}
# 成功插入資料: 崇崇 Daniel
# 處理 URL: https://app.kolradar.com//kol/0d46d871-18e0-4c4f-a99c-6ea64d38e59b?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0d46d871-18e0-4c4f-a99c-6ea64d38e59b?from=socialAccountRanking', 'kol_name': 'DIZZY DIZZO ★ 蔡詩芸', 'kol_ig_id': 'dizzydizzo', 'kol_ig_link': 'https://www.instagram.com/dizzydizzo/', 'type': '日常話題、穿搭、節慶'}
# 成功插入資料: DIZZY DIZZO ★ 蔡詩芸
# 處理 URL: https://app.kolradar.com//kol/85e42bb1-1034-4ca2-85b8-a0cd4e32653f?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/85e42bb1-1034-4ca2-85b8-a0cd4e32653f?from=socialAccountRanking', 'kol_name': '於沁人', 'kol_ig_id': 'dododo_yu', 'kol_ig_link': 'https://www.instagram.com/dododo_yu/', 'type': '日常話題、旅遊、穿搭'}
# 成功插入資料: 於沁人
# 處理 URL: https://app.kolradar.com//kol/e1b90364-0179-4dcf-a9bf-f4e5ecc77ce2?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/e1b90364-0179-4dcf-a9bf-f4e5ecc77ce2?from=socialAccountRanking', 'kol_name': 'YuYu', 'kol_ig_id': 'eehyxyu_', 'kol_ig_link': 'https://www.instagram.com/eehyxyu_/', 'type': '醫美、日常話題、命理占卜'}
# 成功插入資料: YuYu
# 處理 URL: https://app.kolradar.com//kol/7f42a659-31bf-45d4-af90-bef923c3d9a3?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/7f42a659-31bf-45d4-af90-bef923c3d9a3?from=socialAccountRanking', 'kol_name': '2人目のエガちゃん', 'kol_ig_id': 'channega', 'kol_ig_link': 'https://www.instagram.com/channega/?igshid=fgs8qf3b9mn1', 'type': '醫美、日常話題、遊戲'}
# 成功插入資料: 2人目のエガちゃん
# 處理 URL: https://app.kolradar.com//kol/3fb0e7f0-5b8c-44b7-8bd3-c5c013062a5d?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/3fb0e7f0-5b8c-44b7-8bd3-c5c013062a5d?from=socialAccountRanking', 'kol_name': 'Elly Lin', 'kol_ig_id': 'elly0_307', 'kol_ig_link': 'https://www.instagram.com/elly0_307/', 'type': '東南亞旅遊、命理占卜、交通工具'}
# 成功插入資料: Elly Lin
# 處理 URL: https://app.kolradar.com//kol/29bbe317-7b58-4524-afe1-9539372bd530?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/29bbe317-7b58-4524-afe1-9539372bd530?from=socialAccountRanking', 'kol_name': 'EMO老師 ｜國英作文/多益秘笈', 'kol_ig_id': 'emo.english.learn', 'kol_ig_link': 'https://www.instagram.com/emo.english.learn?igsh=MW9pMXIxd2JvNzYxOA%3D%3D', 'type': '升學、教育與學習'}
# 成功插入資料: EMO老師 ｜國英作文/多益秘笈
# 處理 URL: https://app.kolradar.com//kol/d3658f33-63f2-4619-8e26-61346616fae2?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/d3658f33-63f2-4619-8e26-61346616fae2?from=socialAccountRanking', 'kol_name': 'Eric Chen', 'kol_ig_id': 'cheneric924', 'kol_ig_link': 'https://www.instagram.com/cheneric924/', 'type': 'Podcast、家庭、旅遊'}
# 成功插入資料: Eric Chen
# 處理 URL: https://app.kolradar.com//kol/6dcae533-09d6-49f2-9dd5-979d71ab1c80?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6dcae533-09d6-49f2-9dd5-979d71ab1c80?from=socialAccountRanking', 'kol_name': 'Evan健身教練', 'kol_ig_id': 'ddk_evan', 'kol_ig_link': 'https://www.instagram.com/ddk_evan/', 'type': '健身、運動'}
# 成功插入資料: Evan健身教練
# 處理 URL: https://app.kolradar.com//kol/c479db87-147e-481c-847d-a406b1018fa3?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/c479db87-147e-481c-847d-a406b1018fa3?from=socialAccountRanking', 'kol_name': 'FiFi 吳三歲', 'kol_ig_id': 'fifiwu1021', 'kol_ig_link': 'https://www.instagram.com/fifiwu1021/', 'type': '母嬰、婚禮、親子、家庭、醫療與健康、旅遊'}
# 成功插入資料: FiFi 吳三歲
# 處理 URL: https://app.kolradar.com//kol/6314bddb-8570-48bd-8ced-a829ce26174e?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6314bddb-8570-48bd-8ced-a829ce26174e?from=socialAccountRanking', 'kol_name': '姜冠名 aka籃球公道伯', 'kol_ig_id': 'gmsohandsome', 'kol_ig_link': 'https://www.instagram.com/gmsohandsome/', 'type': '籃球、運動'}
# 成功插入資料: 姜冠名 aka籃球公道伯
# 處理 URL: https://app.kolradar.com//kol/f7e84b42-ca9c-4001-b928-98d532fd4f62?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/f7e84b42-ca9c-4001-b928-98d532fd4f62?from=socialAccountRanking', 'kol_name': 'Grace Cooking', 'kol_ig_id': 'grace.cookingtw', 'kol_ig_link': 'https://www.instagram.com/grace.cookingtw/', 'type': '美食、食譜'}
# 成功插入資料: Grace Cooking
# 處理 URL: https://app.kolradar.com//kol/8284d322-8a67-4cc5-a871-8e88a39c6f20?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/8284d322-8a67-4cc5-a871-8e88a39c6f20?from=socialAccountRanking', 'kol_name': 'Terry Chen', 'kol_ig_id': 'master.terry.chen', 'kol_ig_link': 'https://www.instagram.com/master.terry.chen', 'type': '投資、日常話題、財經'}
# 成功插入資料: Terry Chen
# 處理 URL: https://app.kolradar.com//kol/66be78c0-1a34-42cf-b5c3-20889b4b10a3?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/66be78c0-1a34-42cf-b5c3-20889b4b10a3?from=socialAccountRanking', 'kol_name': 'Hailey 莫彩曦', 'kol_ig_id': 'hailey_jane', 'kol_ig_link': 'https://www.instagram.com/hailey_jane/', 'type': '親子、促購導購、日常話題、家庭、美食、旅遊'}
# 成功插入資料: Hailey 莫彩曦
# 處理 URL: https://app.kolradar.com//kol/20ad64b0-de5a-46e6-9341-b4a411231ab7?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/20ad64b0-de5a-46e6-9341-b4a411231ab7?from=socialAccountRanking', 'kol_name': '雞腿妹陳陳', 'kol_ig_id': 'a_chen1994', 'kol_ig_link': 'https://www.instagram.com/a_chen1994/', 'type': '親子旅遊、美食'}
# 成功插入資料: 雞腿妹陳陳
# 處理 URL: https://app.kolradar.com//kol/b9d53301-17b6-4517-af7d-36529e3da054?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/b9d53301-17b6-4517-af7d-36529e3da054?from=socialAccountRanking', 'kol_name': '豪帥🐯', 'kol_ig_id': 'hao0603', 'kol_ig_link': 'https://www.instagram.com/hao0603/', 'type': '登山攀岩'}
# 成功插入資料: 豪帥🐯
# 處理 URL: https://app.kolradar.com//kol/2fb3d179-beb5-4aa3-b140-3d0a1a602e66?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/2fb3d179-beb5-4aa3-b140-3d0a1a602e66?from=socialAccountRanking', 'kol_name': 'Heaven Raven', 'kol_ig_id': 'heavenravenofficial', 'kol_ig_link': 'https://www.instagram.com/heavenravenofficial/', 'type': '電影、藝術與娛樂、美妝時尚、運動'}
# 成功插入資料: Heaven Raven
# 處理 URL: https://app.kolradar.com//kol/44a9b426-799e-4a8f-adaa-cabea2c9e4ec?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/44a9b426-799e-4a8f-adaa-cabea2c9e4ec?from=socialAccountRanking', 'kol_name': '黒木太太', 'kol_ig_id': 'heimutaytay', 'kol_ig_link': 'https://www.instagram.com/heimutaytay/', 'type': '教育與學習、家庭、美食、旅遊、穿搭'}
# 成功插入資料: 黒木太太
# 處理 URL: https://app.kolradar.com//kol/4fac7938-0b24-43f5-8d1c-7d085a7ebfd1?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/4fac7938-0b24-43f5-8d1c-7d085a7ebfd1?from=socialAccountRanking', 'kol_name': 'HOOK', 'kol_ig_id': 'helloiamhook', 'kol_ig_link': 'https://www.instagram.com/helloiamhook/', 'type': '3C家電、美妝時尚、日常話題、美食、旅遊、飲料'}
# 成功插入資料: HOOK
# 處理 URL: https://app.kolradar.com//kol/b83cd343-f3f2-4a52-bd9b-518d04a3a503?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/b83cd343-f3f2-4a52-bd9b-518d04a3a503?from=socialAccountRanking', 'kol_name': 'HowHow', 'kol_ig_id': 'howhowhasfriends', 'kol_ig_link': 'https://www.instagram.com/howhowhasfriends/', 'type': '營養與保健、田徑、馬拉松、日常話題、美食、命理占卜、遊戲、運動'}
# 成功插入資料: HowHow
# 處理 URL: https://app.kolradar.com//kol/15bbf9db-6910-4990-bc45-f841d9511e57?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/15bbf9db-6910-4990-bc45-f841d9511e57?from=socialAccountRanking', 'kol_name': "I'M CHAMPION 🏆", 'kol_ig_id': '1005champion', 'kol_ig_link': 'https://www.instagram.com/1005champion/', 'type': '台灣旅遊、LGBT、日常話題、家庭、醫療與健康、旅遊'}
# 成功插入資料: I'M CHAMPION 🏆
# 處理 URL: https://app.kolradar.com//kol/8fbb0b35-68fe-4c7b-a0fd-f98e38421945?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/8fbb0b35-68fe-4c7b-a0fd-f98e38421945?from=socialAccountRanking', 'kol_name': 'Jonas Tjäder', 'kol_ig_id': 'jonas.tjd', 'kol_ig_link': 'https://www.instagram.com/jonas.tjd/', 'type': '房地產、日常話題'}
# 成功插入資料: Jonas Tjäder
# 處理 URL: https://app.kolradar.com//kol/3700d5f9-6527-4783-8f69-886182297c4f?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/3700d5f9-6527-4783-8f69-886182297c4f?from=socialAccountRanking', 'kol_name': 'Ian Lee', 'kol_ig_id': 'ilee0223', 'kol_ig_link': 'https://www.instagram.com/ilee0223/', 'type': 'Podcast、旅遊'}
# 成功插入資料: Ian Lee
# 處理 URL: https://app.kolradar.com//kol/1c82cfce-e8de-46e2-9758-3dd2871c790e?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/1c82cfce-e8de-46e2-9758-3dd2871c790e?from=socialAccountRanking', 'kol_name': 'IR\U0001fa75Hsing Yi', 'kol_ig_id': 'ir47363', 'kol_ig_link': 'https://www.instagram.com/ir47363/', 'type': '美食、旅遊、飲料、日本旅遊'}
# 成功插入資料: IR🩵Hsing Yi
# 處理 URL: https://app.kolradar.com//kol/f0b2bd12-b576-499a-800e-b8d8e5d2a940?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/f0b2bd12-b576-499a-800e-b8d8e5d2a940?from=socialAccountRanking', 'kol_name': 'ISSY 劉易希', 'kol_ig_id': 'issytpc', 'kol_ig_link': 'https://www.instagram.com/issytpc', 'type': '東南亞旅遊、日常話題、美食、旅遊'}
# 成功插入資料: ISSY 劉易希
# 處理 URL: https://app.kolradar.com//kol/ef9ebdda-3d81-42cb-b8fa-126e87c1c4c5?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/ef9ebdda-3d81-42cb-b8fa-126e87c1c4c5?from=socialAccountRanking', 'kol_name': '蔡弘燁 Ivan 아이반', 'kol_ig_id': 'ivantsai0402', 'kol_ig_link': 'https://www.instagram.com/ivantsai0402/', 'type': '戲劇、舞蹈、節慶'}
# 成功插入資料: 蔡弘燁 Ivan 아이반
# 處理 URL: https://app.kolradar.com//kol/db7a0a64-963a-43b5-9e45-9dd991c2f57d?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/db7a0a64-963a-43b5-9e45-9dd991c2f57d?from=socialAccountRanking', 'kol_name': '賤葆ʕ•ᴥ•ʔ✨', 'kol_ig_id': 'jbao_5000', 'kol_ig_link': 'https://www.instagram.com/jbao_5000/', 'type': '3C家電、自行車、日常話題、美食、運動、美髮'}
# 成功插入資料: 賤葆ʕ•ᴥ•ʔ✨
# 處理 URL: https://app.kolradar.com//kol/a6c47059-36bf-45ee-bccc-ac882db51ca2?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a6c47059-36bf-45ee-bccc-ac882db51ca2?from=socialAccountRanking', 'kol_name': 'Jason 學長｜高效成長 x 外商職涯 x 留學申請', 'kol_ig_id': 'jason_career', 'kol_ig_link': 'https://www.instagram.com/jason_career/', 'type': '升學、教育與學習'}
# 成功插入資料: Jason 學長｜高效成長 x 外商職涯 x 留學申請
# 處理 URL: https://app.kolradar.com//kol/0ae3f47c-84f8-419c-93cd-763a63f197ca?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0ae3f47c-84f8-419c-93cd-763a63f197ca?from=socialAccountRanking', 'kol_name': 'Jay Chou 周杰倫', 'kol_ig_id': 'jaychou', 'kol_ig_link': 'https://www.instagram.com/jaychou/', 'type': '藝術與娛樂、日常話題、音樂'}
# 成功插入資料: Jay Chou 周杰倫
# 處理 URL: https://app.kolradar.com//kol/96b65e19-dae8-48d8-a5e6-7b341134b605?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/96b65e19-dae8-48d8-a5e6-7b341134b605?from=socialAccountRanking', 'kol_name': '林智勝', 'kol_ig_id': 'ngayaw_ake', 'kol_ig_link': 'https://www.instagram.com/ngayaw_ake/', 'type': '高爾夫'}
# 成功插入資料: 林智勝
# 處理 URL: https://app.kolradar.com//kol/3d301db9-635f-4867-998b-f8a44c7c105e?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/3d301db9-635f-4867-998b-f8a44c7c105e?from=socialAccountRanking', 'kol_name': 'Jen Hannah', 'kol_ig_id': 'hannah_quinlivan', 'kol_ig_link': 'https://www.instagram.com/hannah_quinlivan/', 'type': '彩妝、日常話題、美髮'}
# 成功插入資料: Jen Hannah
# 處理 URL: https://app.kolradar.com//kol/91781611-1f31-41f7-9062-31c63a26bb8c?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/91781611-1f31-41f7-9062-31c63a26bb8c?from=socialAccountRanking', 'kol_name': 'Jessica Chai', 'kol_ig_id': 'chai_jessica', 'kol_ig_link': 'https://www.instagram.com/chai_jessica/', 'type': '露營、美食、旅遊'}
# 成功插入資料: Jessica Chai
# 處理 URL: https://app.kolradar.com//kol/1b315915-c552-4ebc-8888-34eb33860b73?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/1b315915-c552-4ebc-8888-34eb33860b73?from=socialAccountRanking', 'kol_name': 'Jia Xin’s homecafe', 'kol_ig_id': 'h0mec4fe', 'kol_ig_link': 'https://www.instagram.com/h0mec4fe', 'type': '甜點、美食'}
# 成功插入資料: Jia Xin’s homecafe
# 處理 URL: https://app.kolradar.com//kol/e45cfd91-4d3f-4a48-89e7-e394107b4f60?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/e45cfd91-4d3f-4a48-89e7-e394107b4f60?from=socialAccountRanking', 'kol_name': 'Jimmy CK Chang 張傑明', 'kol_ig_id': 'jimmyckchang', 'kol_ig_link': 'https://www.instagram.com/jimmyckchang?igsh=MWRjcWg1c3RpMHg1dQ%3D%3D', 'type': '高爾夫'}
# 成功插入資料: Jimmy CK Chang 張傑明
# 處理 URL: https://app.kolradar.com//kol/a636f0fc-5f14-40bb-a631-f3df481058fc?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a636f0fc-5f14-40bb-a631-f3df481058fc?from=socialAccountRanking', 'kol_name': 'Joanne Lin｜林喬安🎄', 'kol_ig_id': 'joannelin__', 'kol_ig_link': 'https://www.instagram.com/joannelin__/', 'type': '電影、旅遊'}
# 成功插入資料: Joanne Lin｜林喬安🎄
# 處理 URL: https://app.kolradar.com//kol/d32be03f-1fb3-4a96-bbb9-260164d05e0c?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/d32be03f-1fb3-4a96-bbb9-260164d05e0c?from=socialAccountRanking', 'kol_name': 'Joe Chen 陳喬恩', 'kol_ig_id': 'iam_joechen', 'kol_ig_link': 'https://www.instagram.com/iam_joechen/', 'type': '婚禮、藝術與娛樂、日常話題'}
# 成功插入資料: Joe Chen 陳喬恩
# 處理 URL: https://app.kolradar.com//kol/0d802d20-45fa-4bfd-9fd0-5cf0ca95ee97?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0d802d20-45fa-4bfd-9fd0-5cf0ca95ee97?from=socialAccountRanking', 'kol_name': 'Joeman  九妹', 'kol_ig_id': 'joemanweng', 'kol_ig_link': 'https://www.instagram.com/joemanweng/', 'type': '3C家電、汽車、藝術與娛樂、日常話題、美食、命理占卜'}
# 成功插入資料: Joeman  九妹
# 處理 URL: https://app.kolradar.com//kol/6e9731d2-c996-47de-9e3a-649e2db1fe75?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6e9731d2-c996-47de-9e3a-649e2db1fe75?from=socialAccountRanking', 'kol_name': '原來是John', 'kol_ig_id': 'johnleetrumpet', 'kol_ig_link': 'https://www.instagram.com/johnleetrumpet', 'type': 'LGBT、藝術與娛樂、日常話題、教育與學習、美食、命理占卜、旅遊'}
# 成功插入資料: 原來是John
# 處理 URL: https://app.kolradar.com//kol/6e4bd791-0500-4d67-93c2-13bfdc612627?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6e4bd791-0500-4d67-93c2-13bfdc612627?from=socialAccountRanking', 'kol_name': '高承睿 Kao Cheng Jui_official', 'kol_ig_id': 'kao_cheng_jui.tt', 'kol_ig_link': 'https://www.instagram.com/kao_cheng_jui.tt/', 'type': '網球、運動'}
# 成功插入資料: 高承睿 Kao Cheng Jui_official
# 處理 URL: https://app.kolradar.com//kol/fb0d7edb-0d3a-4044-ab78-046757b5564d?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/fb0d7edb-0d3a-4044-ab78-046757b5564d?from=socialAccountRanking', 'kol_name': 'Kimberlly Chen 陳怡伶', 'kol_ig_id': 'kimberlly_chen', 'kol_ig_link': 'https://www.instagram.com/kimberlly_chen/', 'type': '彩妝、藝術與娛樂、穿搭'}
# 成功插入資料: Kimberlly Chen 陳怡伶
# 處理 URL: https://app.kolradar.com//kol/d930a651-3fe1-4bdc-822e-78eed1a4e382?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/d930a651-3fe1-4bdc-822e-78eed1a4e382?from=socialAccountRanking', 'kol_name': 'Koichiro Kashima / 鹿島 孝一郎', 'kol_ig_id': 'koichirokashima', 'kol_ig_link': 'https://www.instagram.com/koichirokashima/', 'type': '繪畫、日常話題'}
# 成功插入資料: Koichiro Kashima / 鹿島 孝一郎
# 處理 URL: https://app.kolradar.com//kol/3ab60b50-dcb2-4c26-839e-969767f64a2c?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/3ab60b50-dcb2-4c26-839e-969767f64a2c?from=socialAccountRanking', 'kol_name': '曲奇放克', 'kol_ig_id': 'kookiefunk', 'kol_ig_link': 'https://www.instagram.com/kookiefunk/', 'type': '語言學習、藝術與娛樂、日常話題、教育與學習、運動'}
# 成功插入資料: 曲奇放克
# 處理 URL: https://app.kolradar.com//kol/0bc4c92f-7843-4cc7-837b-51921d60edb2?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0bc4c92f-7843-4cc7-837b-51921d60edb2?from=socialAccountRanking', 'kol_name': '章魚 뭉어｜最台韓國人｜美妝創作者', 'kol_ig_id': 'kr.seafood', 'kol_ig_link': 'https://www.instagram.com/kr.seafood/', 'type': '韓國旅遊、日常話題'}
# 成功插入資料: 章魚 뭉어｜最台韓國人｜美妝創作者
# 處理 URL: https://app.kolradar.com//kol/b1bd1ba1-025f-4ba7-a13a-01e069227fb6?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/b1bd1ba1-025f-4ba7-a13a-01e069227fb6?from=socialAccountRanking', 'kol_name': '✞ 𝐊𝐲𝐮𝐮 ✞', 'kol_ig_id': 'kyuu91', 'kol_ig_link': 'https://www.instagram.com/kyuu91/', 'type': '東南亞旅遊、日常話題、音樂'}
# 成功插入資料: ✞ 𝐊𝐲𝐮𝐮 ✞
# 處理 URL: https://app.kolradar.com//kol/6c67e107-7714-40c9-a59a-179754c3e16c?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6c67e107-7714-40c9-a59a-179754c3e16c?from=socialAccountRanking', 'kol_name': 'Lee／李君', 'kol_ig_id': 'aj_lee.chuan', 'kol_ig_link': 'https://www.instagram.com/aj_lee.chuan', 'type': '甜點、美食、食譜'}
# 成功插入資料: Lee／李君
# 處理 URL: https://app.kolradar.com//kol/f70e9ba4-cfbf-4a43-994c-6a3f19237a10?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/f70e9ba4-cfbf-4a43-994c-6a3f19237a10?from=socialAccountRanking', 'kol_name': '難搞公主雯雯👸🏻', 'kol_ig_id': 'lexilin.tw', 'kol_ig_link': 'https://www.instagram.com/lexilin.tw/', 'type': '婚姻、家庭'}
# 成功插入資料: 難搞公主雯雯👸🏻
# 處理 URL: https://app.kolradar.com//kol/549c00cd-0b86-4f96-b02b-a4aac80eb1e9?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/549c00cd-0b86-4f96-b02b-a4aac80eb1e9?from=socialAccountRanking', 'kol_name': '六艾司 a.k.a. 小冰 Lilice', 'kol_ig_id': 'yenchingsu', 'kol_ig_link': 'https://www.instagram.com/yenchingsu/', 'type': '3C家電、促購導購、甜點、日常話題、教育與學習'}
# 成功插入資料: 六艾司 a.k.a. 小冰 Lilice
# 處理 URL: https://app.kolradar.com//kol/8a489e4f-06c9-41f5-b7f7-7974a2b0bff4?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/8a489e4f-06c9-41f5-b7f7-7974a2b0bff4?from=socialAccountRanking', 'kol_name': 'Lilliannnnnnnnnnnnn', 'kol_ig_id': 'lillianmin_', 'kol_ig_link': 'https://www.instagram.com/lillianmin_/', 'type': '職場、台灣旅遊、交通工具、旅遊'}
# 成功插入資料: Lilliannnnnnnnnnnnn
# 處理 URL: https://app.kolradar.com//kol/fab1ffb0-686d-455d-a345-747ec355adad?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/fab1ffb0-686d-455d-a345-747ec355adad?from=socialAccountRanking', 'kol_name': '超級熱狗王 林敬傑  IFBB PRO', 'kol_ig_id': 'ackj0301_ifbbpro', 'kol_ig_link': 'https://www.instagram.com/ackj0301_ifbbpro', 'type': '健身、日常話題、運動'}
# 成功插入資料: 超級熱狗王 林敬傑  IFBB PRO
# 處理 URL: https://app.kolradar.com//kol/3a16b289-67e3-4d38-8c82-07224506acde?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/3a16b289-67e3-4d38-8c82-07224506acde?from=socialAccountRanking', 'kol_name': '林郁婷 / Lin, Yu-Ting', 'kol_ig_id': 'boxing_ting', 'kol_ig_link': 'https://www.instagram.com/boxing_ting/', 'type': '健身、美妝時尚、運動'}
# 成功插入資料: 林郁婷 / Lin, Yu-Ting
# 處理 URL: https://app.kolradar.com//kol/c1444f27-240f-4133-94fc-83cc13736966?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/c1444f27-240f-4133-94fc-83cc13736966?from=socialAccountRanking', 'kol_name': '李定倫', 'kol_ig_id': 'lun.tw', 'kol_ig_link': 'https://www.instagram.com/lun.tw/', 'type': '日常話題、美食、飲料'}
# 成功插入資料: 李定倫
# 處理 URL: https://app.kolradar.com//kol/11282d7c-ea47-4e02-ad29-8378e08df626?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/11282d7c-ea47-4e02-ad29-8378e08df626?from=socialAccountRanking', 'kol_name': 'Lyle Lin 林家正', 'kol_ig_id': 'lyle_lin_', 'kol_ig_link': 'https://www.instagram.com/lyle_lin_/', 'type': '棒球、日常話題、財經、法政社會'}
# 成功插入資料: Lyle Lin 林家正
# 處理 URL: https://app.kolradar.com//kol/fac0cad8-db09-4ca3-90c0-052c0b880bb2?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/fac0cad8-db09-4ca3-90c0-052c0b880bb2?from=socialAccountRanking', 'kol_name': '慕凡', 'kol_ig_id': 'mufan.art', 'kol_ig_link': 'https://www.instagram.com/mufan.art', 'type': '繪畫、日常話題'}
# 成功插入資料: 慕凡
# 處理 URL: https://app.kolradar.com//kol/24199b9a-d51f-4d53-8dcb-8f141873d96d?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/24199b9a-d51f-4d53-8dcb-8f141873d96d?from=socialAccountRanking', 'kol_name': 'Mao', 'kol_ig_id': 'maochiachun', 'kol_ig_link': 'https://www.instagram.com/maochiachun', 'type': '自行車、職場、運動、旅遊'}
# 成功插入資料: Mao
# 處理 URL: https://app.kolradar.com//kol/85e4cf5f-647c-4bd7-82e1-b909c82aba2d?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/85e4cf5f-647c-4bd7-82e1-b909c82aba2d?from=socialAccountRanking', 'kol_name': '高均數學/升學帳', 'kol_ig_id': 'mathtutorkao', 'kol_ig_link': 'https://www.instagram.com/mathtutorkao/', 'type': '升學、教育與學習'}
# 成功插入資料: 高均數學/升學帳
# 處理 URL: https://app.kolradar.com//kol/311aa220-67df-4178-8be8-f02e356f7ad9?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/311aa220-67df-4178-8be8-f02e356f7ad9?from=socialAccountRanking', 'kol_name': '粿粿ᴍᴇɪɢᴏ', 'kol_ig_id': 'meigo.c', 'kol_ig_link': 'https://www.instagram.com/meigo.c', 'type': '3C家電、室內外設計、日常話題、家庭、穿搭、節慶'}
# 成功插入資料: 粿粿ᴍᴇɪɢᴏ
# 處理 URL: https://app.kolradar.com//kol/3ec99943-b3f5-4c25-bc7b-a38162dc2740?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/3ec99943-b3f5-4c25-bc7b-a38162dc2740?from=socialAccountRanking', 'kol_name': '𝐌𝐢𝐚簡單生活日記', 'kol_ig_id': 'muserry_daily', 'kol_ig_link': 'https://www.instagram.com/muserry_daily/', 'type': '美食、生活風格、日本旅遊'}
# 成功插入資料: 𝐌𝐢𝐚簡單生活日記
# 處理 URL: https://app.kolradar.com//kol/83b0dd77-7bcf-4fd9-bb1a-047681dc318d?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/83b0dd77-7bcf-4fd9-bb1a-047681dc318d?from=socialAccountRanking', 'kol_name': 'Mia米亞🎀', 'kol_ig_id': 'miababy0122', 'kol_ig_link': 'https://www.instagram.com/miababy0122/', 'type': '自行車、機車'}
# 成功插入資料: Mia米亞🎀
# 處理 URL: https://app.kolradar.com//kol/b1807009-80b6-48cb-8662-f44b750f2c40?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/b1807009-80b6-48cb-8662-f44b750f2c40?from=socialAccountRanking', 'kol_name': 'michelle yuan', 'kol_ig_id': 'michelleyuan', 'kol_ig_link': 'https://www.instagram.com/michelleyuan/', 'type': '網球'}
# 成功插入資料: michelle yuan
# 處理 URL: https://app.kolradar.com//kol/c9c342b1-72b9-4829-a744-ccd2b0bea418?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/c9c342b1-72b9-4829-a744-ccd2b0bea418?from=socialAccountRanking', 'kol_name': 'Milly🤍鈺婷', 'kol_ig_id': 'millyly', 'kol_ig_link': 'https://www.instagram.com/millyly/?g=5', 'type': '瑜珈'}
# 成功插入資料: Milly🤍鈺婷
# 處理 URL: https://app.kolradar.com//kol/3dd9d0a8-5a47-47dd-8401-2f3d4426a74e?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/3dd9d0a8-5a47-47dd-8401-2f3d4426a74e?from=socialAccountRanking', 'kol_name': 'M͙i͙n͙a͙ L͙. 🌸 Chun Liao', 'kol_ig_id': 'minagram____', 'kol_ig_link': 'https://www.instagram.com/minagram____/', 'type': '婚姻、家庭'}
# 成功插入資料: M͙i͙n͙a͙ L͙. 🌸 Chun Liao
# 處理 URL: https://app.kolradar.com//kol/927f6de3-0b43-4fd9-a2ac-472fc9620ffa?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/927f6de3-0b43-4fd9-a2ac-472fc9620ffa?from=socialAccountRanking', 'kol_name': '瘦子E.SO', 'kol_ig_id': 'mjfceo', 'kol_ig_link': 'https://www.instagram.com/mjfceo/', 'type': '香水、甜點、日常話題、飲料'}
# 成功插入資料: 瘦子E.SO
# 處理 URL: https://app.kolradar.com//kol/48ddcc99-5033-4ae0-9f02-5cf1ee915d45?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/48ddcc99-5033-4ae0-9f02-5cf1ee915d45?from=socialAccountRanking', 'kol_name': 'Daisy', 'kol_ig_id': 'hithisisdaisy', 'kol_ig_link': 'https://www.instagram.com/hithisisdaisy/', 'type': '彩妝、美髮'}
# 成功插入資料: Daisy
# 處理 URL: https://app.kolradar.com//kol/cc4a7eec-bb23-4a93-84f9-49600f47cbf5?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/cc4a7eec-bb23-4a93-84f9-49600f47cbf5?from=socialAccountRanking', 'kol_name': 'Nancy Wang 王虹之', 'kol_ig_id': 'wasinancy', 'kol_ig_link': 'https://www.instagram.com/wasinancy/', 'type': '瑜珈、藝術與娛樂、教育與學習'}
# 成功插入資料: Nancy Wang 王虹之
# 處理 URL: https://app.kolradar.com//kol/bb9ef9c5-628d-48b9-b2f0-392a21287b7b?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/bb9ef9c5-628d-48b9-b2f0-392a21287b7b?from=socialAccountRanking', 'kol_name': '冠瑜', 'kol_ig_id': 'unique.huang', 'kol_ig_link': 'https://www.instagram.com/unique.huang/', 'type': '瑜珈'}
# 成功插入資料: 冠瑜
# 處理 URL: https://app.kolradar.com//kol/cfae6488-30ae-4930-b505-4302a8938dd5?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/cfae6488-30ae-4930-b505-4302a8938dd5?from=socialAccountRanking', 'kol_name': '那對夫妻Nico&amp;Kim', 'kol_ig_id': '1006nk', 'kol_ig_link': 'https://www.instagram.com/1006nk/', 'type': '親子、成人、藝術與娛樂、日常話題、教育與學習、家庭'}
# 成功插入資料: 那對夫妻Nico&amp;Kim
# 處理 URL: https://app.kolradar.com//kol/6ed56d05-2441-4cb5-a9df-e49f1ecd12b7?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6ed56d05-2441-4cb5-a9df-e49f1ecd12b7?from=socialAccountRanking', 'kol_name': '天后闆妹', 'kol_ig_id': 'ban.mei.onnnnni', 'kol_ig_link': 'https://www.instagram.com/ban.mei.onnnnni/', 'type': '韓國旅遊、Podcast、日常話題、家庭、遊戲、節慶'}
# 成功插入資料: 天后闆妹
# 處理 URL: https://app.kolradar.com//kol/65a26288-596d-4d73-b113-72e9d512651c?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/65a26288-596d-4d73-b113-72e9d512651c?from=socialAccountRanking', 'kol_name': '老咩的家𖠿꙳', 'kol_ig_id': 'oldgirl.homelife', 'kol_ig_link': 'https://www.instagram.com/oldgirl.homelife/', 'type': '室內外設計'}
# 成功插入資料: 老咩的家𖠿꙳
# 處理 URL: https://app.kolradar.com//kol/fb342ec2-58ef-44a8-a8be-d7e6cbb7b037?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/fb342ec2-58ef-44a8-a8be-d7e6cbb7b037?from=socialAccountRanking', 'kol_name': 'ØZI', 'kol_ig_id': 'ozifp', 'kol_ig_link': 'https://www.instagram.com/ozifp/', 'type': '手機遊戲、藝術與娛樂、日常話題、遊戲'}
# 成功插入資料: ØZI
# 處理 URL: https://app.kolradar.com//kol/a61d792a-0ec8-4485-b2ed-0ef46d4e6fc9?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a61d792a-0ec8-4485-b2ed-0ef46d4e6fc9?from=socialAccountRanking', 'kol_name': '派偉俊 Patrick Brasca', 'kol_ig_id': 'patrickbrasca', 'kol_ig_link': 'https://www.instagram.com/patrickbrasca/', 'type': '流行音樂、日常話題、音樂'}
# 成功插入資料: 派偉俊 Patrick Brasca
# 處理 URL: https://app.kolradar.com//kol/1eb39a94-2b79-4c61-bf59-1fc92f5dcf42?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/1eb39a94-2b79-4c61-bf59-1fc92f5dcf42?from=socialAccountRanking', 'kol_name': 'Paula Hsu art🌟', 'kol_ig_id': 'paulahsuart', 'kol_ig_link': 'https://www.instagram.com/paulahsuart/', 'type': '繪畫、日常話題'}
# 成功插入資料: Paula Hsu art🌟
# 處理 URL: https://app.kolradar.com//kol/3ea91be0-90d9-4a00-b70b-1dc1c4a59db0?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/3ea91be0-90d9-4a00-b70b-1dc1c4a59db0?from=socialAccountRanking', 'kol_name': 'Peggy Chen', 'kol_ig_id': 'mandarinwithpeggy', 'kol_ig_link': 'https://www.instagram.com/mandarinwithpeggy/', 'type': 'Podcast、藝術與娛樂'}
# 成功插入資料: Peggy Chen
# 處理 URL: https://app.kolradar.com//kol/d16aac5b-10c2-4849-b2bc-c40be6f331a8?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/d16aac5b-10c2-4849-b2bc-c40be6f331a8?from=socialAccountRanking', 'kol_name': 'PUZZLEMAN', 'kol_ig_id': 'puzzlemantpe', 'kol_ig_link': 'https://www.instagram.com/puzzlemantpe/', 'type': '登山攀岩'}
# 成功插入資料: PUZZLEMAN
# 處理 URL: https://app.kolradar.com//kol/ac522c9a-bfad-4cdd-8c1e-9dabe2fc85af?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/ac522c9a-bfad-4cdd-8c1e-9dabe2fc85af?from=socialAccountRanking', 'kol_name': '陳晨威', 'kol_ig_id': 'c.c.w____98', 'kol_ig_link': 'https://www.instagram.com/c.c.w____98/', 'type': '棒球、運動'}
# 成功插入資料: 陳晨威
# 處理 URL: https://app.kolradar.com//kol/456e2014-58dd-48f5-9ce1-1dce0569959e?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/456e2014-58dd-48f5-9ce1-1dce0569959e?from=socialAccountRanking', 'kol_name': 'Ray Chen', 'kol_ig_id': 'raychen09', 'kol_ig_link': 'https://www.instagram.com/raychen09/', 'type': '籃球、運動'}
# 成功插入資料: Ray Chen
# 處理 URL: https://app.kolradar.com//kol/5e75b997-8bd9-4c10-8541-7f244536a176?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/5e75b997-8bd9-4c10-8541-7f244536a176?from=socialAccountRanking', 'kol_name': '鈴鈴一家', 'kol_ig_id': 'ringringthecat', 'kol_ig_link': 'https://www.instagram.com/ringringthecat/', 'type': '手機遊戲'}
# 成功插入資料: 鈴鈴一家
# 處理 URL: https://app.kolradar.com//kol/b2014450-9811-4b15-8af4-d2b01c79605d?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/b2014450-9811-4b15-8af4-d2b01c79605d?from=socialAccountRanking', 'kol_name': '𝑹𝒊𝒏𝑹𝒊𝒏台湾留学☃︎𝑯𝒂𝒑𝒑𝒚 𝒅𝒂𝒊𝒍𝒚', 'kol_ig_id': 'yummmy995', 'kol_ig_link': 'https://www.instagram.com/yummmy995/', 'type': '語言學習、家庭、美食'}
# 成功插入資料: 𝑹𝒊𝒏𝑹𝒊𝒏台湾留学☃︎𝑯𝒂𝒑𝒑𝒚 𝒅𝒂𝒊𝒍𝒚
# 處理 URL: https://app.kolradar.com//kol/efb220d6-a2b9-4f06-898e-e0f5f2a1380d?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/efb220d6-a2b9-4f06-898e-e0f5f2a1380d?from=socialAccountRanking', 'kol_name': 'Roxanne 蘿珊', 'kol_ig_id': 'roxanne.ch', 'kol_ig_link': 'https://www.instagram.com/roxanne.ch/', 'type': '東南亞旅遊、教育與學習、旅遊、節慶'}
# 成功插入資料: Roxanne 蘿珊
# 處理 URL: https://app.kolradar.com//kol/b42a538e-0de7-4163-86cf-fae4394f8bfb?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/b42a538e-0de7-4163-86cf-fae4394f8bfb?from=socialAccountRanking', 'kol_name': 'run_n 阿信👓™.', 'kol_ig_id': 'run_n', 'kol_ig_link': 'https://www.instagram.com/run_n/', 'type': '婚禮、親子、交通工具'}
# 成功插入資料: run_n 阿信👓™.
# 處理 URL: https://app.kolradar.com//kol/57e8a82f-8e12-4e76-8235-5b8009875692?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/57e8a82f-8e12-4e76-8235-5b8009875692?from=socialAccountRanking', 'kol_name': 'Ru儒哥', 'kol_ig_id': 'ruge1222', 'kol_ig_link': 'https://www.instagram.com/ruge1222', 'type': '手機遊戲、日常話題、家庭、命理占卜、攝影、運動'}
# 成功插入資料: Ru儒哥
# 處理 URL: https://app.kolradar.com//kol/c5e9cd7a-a9a9-4d9a-a45c-409c095f3462?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/c5e9cd7a-a9a9-4d9a-a45c-409c095f3462?from=socialAccountRanking', 'kol_name': 'sᴀɴᴅʏ&amp;ᴍᴀɴᴅʏ', 'kol_ig_id': 'sandymandy_official', 'kol_ig_link': 'https://www.instagram.com/sandymandy_official/', 'type': '舞蹈、藝術與娛樂、日常話題、運動、音樂'}
# 成功插入資料: sᴀɴᴅʏ&amp;ᴍᴀɴᴅʏ
# 處理 URL: https://app.kolradar.com//kol/07f74d83-3bda-493b-ad98-306a118322b8?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/07f74d83-3bda-493b-ad98-306a118322b8?from=socialAccountRanking', 'kol_name': '♥selina♡', 'kol_ig_id': 'selinanahaha', 'kol_ig_link': 'https://www.instagram.com/selinanahaha/', 'type': '母嬰、婦女醫學、日常話題、美食、醫療與健康'}
# 成功插入資料: ♥selina♡
# 處理 URL: https://app.kolradar.com//kol/bf923be9-cdc1-4aa2-885e-2538eb5addb3?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/bf923be9-cdc1-4aa2-885e-2538eb5addb3?from=socialAccountRanking', 'kol_name': 'SHKEV 雪可', 'kol_ig_id': 'shkev_', 'kol_ig_link': 'https://www.instagram.com/shkev_/', 'type': '促購導購、日常話題、穿搭'}
# 成功插入資料: SHKEV 雪可
# 處理 URL: https://app.kolradar.com//kol/8e33aeda-afbf-4212-8b03-2122f534a632?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/8e33aeda-afbf-4212-8b03-2122f534a632?from=socialAccountRanking', 'kol_name': 'Shuai Li', 'kol_ig_id': 'shuaisoserious', 'kol_ig_link': 'https://www.instagram.com/shuaisoserious/', 'type': '健身、遊戲'}
# 成功插入資料: Shuai Li
# 處理 URL: https://app.kolradar.com//kol/6344c7d7-4f3f-418d-bc48-be2e7f2e1185?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6344c7d7-4f3f-418d-bc48-be2e7f2e1185?from=socialAccountRanking', 'kol_name': 'shushu自由研究所｜日本旅遊住宿・美食・路上風景', 'kol_ig_id': 'shushufreedom', 'kol_ig_link': 'https://www.instagram.com/shushufreedom/', 'type': '台灣旅遊、美食、旅遊、日本旅遊'}
# 成功插入資料: shushu自由研究所｜日本旅遊住宿・美食・路上風景
# 處理 URL: https://app.kolradar.com//kol/0958743d-1082-4b80-820e-c3d2519d3f4a?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0958743d-1082-4b80-820e-c3d2519d3f4a?from=socialAccountRanking', 'kol_name': 'silvia', 'kol_ig_id': 'cortney80214', 'kol_ig_link': 'https://www.instagram.com/cortney80214/', 'type': '台灣旅遊、教育與學習、美食、寵物'}
# 成功插入資料: silvia
# 處理 URL: https://app.kolradar.com//kol/f41d40f8-d9b8-49bc-9743-0638dd4fcff3?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/f41d40f8-d9b8-49bc-9743-0638dd4fcff3?from=socialAccountRanking', 'kol_name': 'Soupy Tang 湯舒皮', 'kol_ig_id': 'soupytang', 'kol_ig_link': 'https://www.instagram.com/soupytang/', 'type': '手作、美妝時尚、日常話題、美食、生活風格'}
# 成功插入資料: Soupy Tang 湯舒皮
# 處理 URL: https://app.kolradar.com//kol/eca18489-d9c6-41c6-b90c-149a81e4c0df?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/eca18489-d9c6-41c6-b90c-149a81e4c0df?from=socialAccountRanking', 'kol_name': 'Stanley 史丹利', 'kol_ig_id': 'stanley.wang.234', 'kol_ig_link': 'https://www.instagram.com/stanley.wang.234/', 'type': '電腦遊戲、實況、日常話題、遊戲'}
# 成功插入資料: Stanley 史丹利
# 處理 URL: https://app.kolradar.com//kol/c1264039-b142-425d-859b-3662e44a0df6?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/c1264039-b142-425d-859b-3662e44a0df6?from=socialAccountRanking', 'kol_name': 'Suani ♥理萱♥', 'kol_ig_id': 'suanibaby', 'kol_ig_link': 'https://www.instagram.com/suanibaby/', 'type': '醫美、手作、美妝時尚、美食、美髮、穿搭'}
# 成功插入資料: Suani ♥理萱♥
# 處理 URL: https://app.kolradar.com//kol/f5b632c8-1016-4294-a714-daa97adc3ba1?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/f5b632c8-1016-4294-a714-daa97adc3ba1?from=socialAccountRanking', 'kol_name': 'Sunny Wang 王陽明', 'kol_ig_id': 'sunnyboyyy', 'kol_ig_link': 'https://www.instagram.com/sunnyboyyy/', 'type': '電影、家庭、美食、法政社會、運動'}
# 成功插入資料: Sunny Wang 王陽明
# 處理 URL: https://app.kolradar.com//kol/7899a11a-24b7-4041-a000-44d2390846b3?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/7899a11a-24b7-4041-a000-44d2390846b3?from=socialAccountRanking', 'kol_name': 'SwissNara🌈', 'kol_ig_id': 'flakesofrainbow', 'kol_ig_link': 'https://www.instagram.com/flakesofrainbow/', 'type': '語言學習、婚禮、家庭'}
# 成功插入資料: SwissNara🌈
# 處理 URL: https://app.kolradar.com//kol/8d13cdfc-0e00-40ff-907e-f0433d165175?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/8d13cdfc-0e00-40ff-907e-f0433d165175?from=socialAccountRanking', 'kol_name': 'Sydney Sie 謝昕妮', 'kol_ig_id': 'sydneysie', 'kol_ig_link': 'https://www.instagram.com/sydneysie/', 'type': '語言學習、藝術與娛樂、美妝時尚、日常話題'}
# 成功插入資料: Sydney Sie 謝昕妮
# 處理 URL: https://app.kolradar.com//kol/551af703-c0f2-42bd-8713-3fdbb2338ae5?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/551af703-c0f2-42bd-8713-3fdbb2338ae5?from=socialAccountRanking', 'kol_name': 'Ten𖥧𖡆𖦥有拱門的家𖤐', 'kol_ig_id': 'wuliten', 'kol_ig_link': 'https://www.instagram.com/wuliten/', 'type': '室內外設計、美妝時尚、美食、生活風格'}
# 成功插入資料: Ten𖥧𖡆𖦥有拱門的家𖤐
# 處理 URL: https://app.kolradar.com//kol/13291748-47ef-4de6-962a-ca28efbda8a3?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/13291748-47ef-4de6-962a-ca28efbda8a3?from=socialAccountRanking', 'kol_name': 'The DoDo Men - 嘟嘟人', 'kol_ig_id': 'thedodomen', 'kol_ig_link': 'https://www.instagram.com/thedodomen/', 'type': 'Podcast、日常話題、教育與學習、法政社會、旅遊'}
# 成功插入資料: The DoDo Men - 嘟嘟人
# 處理 URL: https://app.kolradar.com//kol/eafdcded-ce10-4705-9d7f-a6412c1912de?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/eafdcded-ce10-4705-9d7f-a6412c1912de?from=socialAccountRanking', 'kol_name': 'TTENG', 'kol_ig_id': 'tengwenpo', 'kol_ig_link': 'https://www.instagram.com/tengwenpo/', 'type': '自行車、手機遊戲'}
# 成功插入資料: TTENG
# 處理 URL: https://app.kolradar.com//kol/9289c78d-e4b3-4599-a2d0-6c9d6070b872?from=socialAccountRanking
# 嘗試第 1 次爬取...
# ...
# 成功插入資料: 鐵蛋存錢日記｜存錢投資．體驗人生．分享生活
# 處理 URL: https://app.kolradar.com//kol/a3ae6375-1a43-473f-9f53-b84acfb8618d?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a3ae6375-1a43-473f-9f53-b84acfb8618d?from=socialAccountRanking', 'kol_name': '蕭芷渲𝐈𝐫𝐢𝐬', 'kol_ig_id': 'irisxiao_', 'kol_ig_link': 'https://www.instagram.com/irisxiao_/', 'type': '實況、日常話題、運動、穿搭、節慶'}
# 成功插入資料: 蕭芷渲𝐈𝐫𝐢𝐬
# 處理 URL: https://app.kolradar.com//kol/a430901b-2754-4b2e-bd51-2f5f83f85bd0?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a430901b-2754-4b2e-bd51-2f5f83f85bd0?from=socialAccountRanking', 'kol_name': '阿田', 'kol_ig_id': 'mingtianyou', 'kol_ig_link': 'https://www.instagram.com/mingtianyou/', 'type': '室內外設計、日常話題、寵物、運動、交通工具'}
# 成功插入資料: 阿田
# 處理 URL: https://app.kolradar.com//kol/9d35d0ce-a9d8-4569-8eda-fc127cee33a8?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/9d35d0ce-a9d8-4569-8eda-fc127cee33a8?from=socialAccountRanking', 'kol_name': 'Ken Lin', 'kol_ig_id': 'kenlin125', 'kol_ig_link': 'https://www.instagram.com/kenlin125/', 'type': '戲劇、藝術與娛樂、運動'}
# 成功插入資料: Ken Lin
# 處理 URL: https://app.kolradar.com//kol/87ffb8fb-4750-4b22-ad64-9c4bb465138e?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/87ffb8fb-4750-4b22-ad64-9c4bb465138e?from=socialAccountRanking', 'kol_name': '阿不拉Abura', 'kol_ig_id': '94abura', 'kol_ig_link': 'https://www.instagram.com/94abura/', 'type': '科技、汽車、生活風格'}
# 成功插入資料: 阿不拉Abura
# 處理 URL: https://app.kolradar.com//kol/cb099932-e7c7-4631-9576-1389959404ff?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/cb099932-e7c7-4631-9576-1389959404ff?from=socialAccountRanking', 'kol_name': '阿任 Ren', 'kol_ig_id': '_ren.chen', 'kol_ig_link': 'https://www.instagram.com/_ren.chen/', 'type': '汽車'}
# 成功插入資料: 阿任 Ren
# 處理 URL: https://app.kolradar.com//kol/600a23a5-4d5b-48c9-a698-3d6b5fc5d47c?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/600a23a5-4d5b-48c9-a698-3d6b5fc5d47c?from=socialAccountRanking', 'kol_name': '阿宏機車記', 'kol_ig_id': 'h_motovlog', 'kol_ig_link': 'https://www.instagram.com/h_motovlog', 'type': '機車、汽車、日常話題、運動、交通工具'}
# 成功插入資料: 阿宏機車記
# 處理 URL: https://app.kolradar.com//kol/a34ec11a-0e4f-4d17-ac94-e0689ed50667?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a34ec11a-0e4f-4d17-ac94-e0689ed50667?from=socialAccountRanking', 'kol_name': '阿慈｜倪安慈 Kathy Ngai', 'kol_ig_id': 'ngaionchi_kathy', 'kol_ig_link': 'https://www.instagram.com/ngaionchi_kathy/?hl=zh-hk', 'type': '田徑、馬拉松、運動、旅遊'}
# 成功插入資料: 阿慈｜倪安慈 Kathy Ngai
# 處理 URL: https://app.kolradar.com//kol/d24c8a13-bf57-4b55-a2fb-ec24f06e3895?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/d24c8a13-bf57-4b55-a2fb-ec24f06e3895?from=socialAccountRanking', 'kol_name': '阿滴英文', 'kol_ig_id': 'rayduenglish', 'kol_ig_link': 'https://www.instagram.com/rayduenglish/?hl=zh-tw', 'type': '台灣旅遊、日常話題、教育與學習、美食、旅遊、飲料'}
# 成功插入資料: 阿滴英文
# 處理 URL: https://app.kolradar.com//kol/5b41b9bf-72c4-4163-a2b5-17f128c10d38?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/5b41b9bf-72c4-4163-a2b5-17f128c10d38?from=socialAccountRanking', 'kol_name': 'KamiKami Matsu', 'kol_ig_id': 'ookoukioo', 'kol_ig_link': 'https://www.instagram.com/ookoukioo', 'type': '電腦遊戲、科技、藝術與娛樂、遊戲'}
# 成功插入資料: KamiKami Matsu
# 處理 URL: https://app.kolradar.com//kol/de296de2-28e7-4759-be78-8783f47bb5c0?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/de296de2-28e7-4759-be78-8783f47bb5c0?from=socialAccountRanking', 'kol_name': '阿翰po影片', 'kol_ig_id': 'hanhanpovideo', 'kol_ig_link': 'https://www.instagram.com/hanhanpovideo/', 'type': '營養與保健、3C家電、教育與學習、家庭、美食、旅遊'}
# 成功插入資料: 阿翰po影片
# 處理 URL: https://app.kolradar.com//kol/a314ac8a-f57f-427a-8bed-8dc488562cb3?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a314ac8a-f57f-427a-8bed-8dc488562cb3?from=socialAccountRanking', 'kol_name': '阿聲 JJC', 'kol_ig_id': 'christine__0000', 'kol_ig_link': 'https://www.instagram.com/christine__0000', 'type': '彩妝、狗'}
# 成功插入資料: 阿聲 JJC
# 處理 URL: https://app.kolradar.com//kol/0c5a0aaf-189f-4ddb-a2d6-b1dc5b60b944?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0c5a0aaf-189f-4ddb-a2d6-b1dc5b60b944?from=socialAccountRanking', 'kol_name': '安安🖤', 'kol_ig_id': 'ooxxq60297ya', 'kol_ig_link': 'https://www.instagram.com/ooxxq60297ya/', 'type': '母嬰、親子、彩妝、醫療與健康、保養'}
# 成功插入資料: 安安🖤
# 處理 URL: https://app.kolradar.com//kol/761aa816-9926-484f-b0e4-fe994f6a710b?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/761aa816-9926-484f-b0e4-fe994f6a710b?from=socialAccountRanking', 'kol_name': '陳允澤', 'kol_ig_id': 'bonb.chen', 'kol_ig_link': 'https://www.instagram.com/bonb.chen/', 'type': '香水、美妝時尚、日常話題、保養、穿搭'}
# 成功插入資料: 陳允澤
# 處理 URL: https://app.kolradar.com//kol/994718a9-26b7-464e-b408-57b2743222fd?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/994718a9-26b7-464e-b408-57b2743222fd?from=socialAccountRanking', 'kol_name': '陳冠宇', 'kol_ig_id': 'kuanyu1029', 'kol_ig_link': 'https://www.instagram.com/kuanyu1029/', 'type': '棒球、實況、日常話題、旅遊'}
# 成功插入資料: 陳冠宇
# 處理 URL: https://app.kolradar.com//kol/0a63514c-3d4e-4cb9-affd-9b58a4eb4597?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/0a63514c-3d4e-4cb9-affd-9b58a4eb4597?from=socialAccountRanking', 'kol_name': '陳妮絲 chen chi', 'kol_ig_id': 'babes.8271', 'kol_ig_link': 'https://www.instagram.com/babes.8271/', 'type': '母嬰、日常話題、家庭'}
# 成功插入資料: 陳妮絲 chen chi
# 處理 URL: https://app.kolradar.com//kol/2aa338bc-87e6-4f89-b989-c0665d212183?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/2aa338bc-87e6-4f89-b989-c0665d212183?from=socialAccountRanking', 'kol_name': '陳子豪 #01⚾️', 'kol_ig_id': 'chen_tzu_hao_01', 'kol_ig_link': 'https://www.instagram.com/chen_tzu_hao_01/', 'type': '棒球、籃球、遊戲、運動'}
# 成功插入資料: 陳子豪 #01⚾️
# 處理 URL: https://app.kolradar.com//kol/44dd8a9a-a79e-4de6-9ba2-1ac25f1047d3?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/44dd8a9a-a79e-4de6-9ba2-1ac25f1047d3?from=socialAccountRanking', 'kol_name': '大H 陳建昕 IFBB PRO', 'kol_ig_id': 'hsin0126', 'kol_ig_link': 'https://www.instagram.com/hsin0126/', 'type': '營養與保健、自行車、日常話題、教育與學習、美食、運動'}
# 成功插入資料: 大H 陳建昕 IFBB PRO
# 處理 URL: https://app.kolradar.com//kol/adb937e9-c52c-45f4-bc61-cac2a5df0808?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/adb937e9-c52c-45f4-bc61-cac2a5df0808?from=socialAccountRanking', 'kol_name': '陳彥博 Tommy Chen', 'kol_ig_id': 'tommychen1986', 'kol_ig_link': 'https://www.instagram.com/tommychen1986/', 'type': '田徑、馬拉松、教育與學習、運動'}
# 成功插入資料: 陳彥博 Tommy Chen
# 處理 URL: https://app.kolradar.com//kol/c28e2486-b9cd-4bdb-8b88-9daa592c9ced?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/c28e2486-b9cd-4bdb-8b88-9daa592c9ced?from=socialAccountRanking', 'kol_name': '陳怡君🍬阿咪 🅼🅸🅽🅸', 'kol_ig_id': 'mini780622', 'kol_ig_link': 'https://www.instagram.com/mini780622/', 'type': '台灣旅遊、藝術與娛樂、日常話題、家庭'}
# 成功插入資料: 陳怡君🍬阿咪 🅼🅸🅽🅸
# 處理 URL: https://app.kolradar.com//kol/f09870a4-9fed-4570-99f5-6523cc881619?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/f09870a4-9fed-4570-99f5-6523cc881619?from=socialAccountRanking', 'kol_name': '陳敬宣  Genie', 'kol_ig_id': 'genieechan', 'kol_ig_link': 'https://www.instagram.com/genieechan/', 'type': '韓國旅遊、美妝時尚、日常話題、遊戲、交通工具、旅遊、穿搭'}
# 成功插入資料: 陳敬宣  Genie
# 處理 URL: https://app.kolradar.com//kol/f9c51a8d-0839-49ce-824b-b58f652edbdd?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/f9c51a8d-0839-49ce-824b-b58f652edbdd?from=socialAccountRanking', 'kol_name': '陳陳', 'kol_ig_id': 'ying___0628', 'kol_ig_link': 'https://www.instagram.com/ying___0628/', 'type': '香水、彩妝、保養'}
# 成功插入資料: 陳陳
# 處理 URL: https://app.kolradar.com//kol/2844b87a-2b40-4da6-8785-40a90958525a?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/2844b87a-2b40-4da6-8785-40a90958525a?from=socialAccountRanking', 'kol_name': '陸貳', 'kol_ig_id': '6th_ed2', 'kol_ig_link': 'https://www.instagram.com/6th_ed2/', 'type': '繪畫'}
# 成功插入資料: 陸貳
# 處理 URL: https://app.kolradar.com//kol/fe571859-36e5-4f11-a144-52a61afe1f6b?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/fe571859-36e5-4f11-a144-52a61afe1f6b?from=socialAccountRanking', 'kol_name': '隋棠 Sui Tang', 'kol_ig_id': 'suitangtang', 'kol_ig_link': 'https://www.instagram.com/suitangtang/', 'type': '戲劇、美妝時尚、日常話題、家庭、醫療與健康、保養'}
# 成功插入資料: 隋棠 Sui Tang
# 處理 URL: https://app.kolradar.com//kol/2c586db5-0622-4081-b4d1-b1c5d081fb5b?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/2c586db5-0622-4081-b4d1-b1c5d081fb5b?from=socialAccountRanking', 'kol_name': '𝑳𝒂𝒍𝒂 ｜夏菈', 'kol_ig_id': 'lala._.0412', 'kol_ig_link': 'https://www.instagram.com/lala._.0412/', 'type': '韓國偶像、舞蹈、藝術與娛樂、日常話題'}
# 成功插入資料: 𝑳𝒂𝒍𝒂 ｜夏菈
# 處理 URL: https://app.kolradar.com//kol/10947542-1f33-42f4-8a65-ecf490048eed?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/10947542-1f33-42f4-8a65-ecf490048eed?from=socialAccountRanking', 'kol_name': '雷理莎Lisa Ries', 'kol_ig_id': 'frogygirlz', 'kol_ig_link': 'https://www.instagram.com/frogygirlz/', 'type': '田徑、馬拉松、運動'}
# 成功插入資料: 雷理莎Lisa Ries
# 處理 URL: https://app.kolradar.com//kol/fd5c9f77-5c1d-4f67-b03a-e2b3d62232ad?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/fd5c9f77-5c1d-4f67-b03a-e2b3d62232ad?from=socialAccountRanking', 'kol_name': 'Judy Kim', 'kol_ig_id': 'jy_luv.peace', 'kol_ig_link': 'https://www.instagram.com/jy_luv.peace/', 'type': '韓國旅遊、日常話題、美食、旅遊、保養'}
# 成功插入資料: Judy Kim
# 處理 URL: https://app.kolradar.com//kol/e17df44f-2abf-4326-908f-708f6397c603?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/e17df44f-2abf-4326-908f-708f6397c603?from=socialAccountRanking', 'kol_name': '頑童MJ116', 'kol_ig_id': 'mj116_tpc', 'kol_ig_link': 'https://www.instagram.com/mj116_tpc/', 'type': '香水、藝術與娛樂、日常話題'}
# 成功插入資料: 頑童MJ116
# 處理 URL: https://app.kolradar.com//kol/4952f1f4-4210-4ca2-899c-bfed1532dafd?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/4952f1f4-4210-4ca2-899c-bfed1532dafd?from=socialAccountRanking', 'kol_name': '顏人中 ELE', 'kol_ig_id': 'ele_yan_0617', 'kol_ig_link': 'https://www.instagram.com/ele_yan_0617/', 'type': '流行音樂、飲料'}
# 成功插入資料: 顏人中 ELE
# 處理 URL: https://app.kolradar.com//kol/4fe70f2c-e6c4-42d7-ba64-744761974c0c?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/4fe70f2c-e6c4-42d7-ba64-744761974c0c?from=socialAccountRanking', 'kol_name': '香菇愛畫畫', 'kol_ig_id': 'xianggu0719', 'kol_ig_link': 'https://www.instagram.com/xianggu0719/', 'type': '婚姻、家庭'}
# 成功插入資料: 香菇愛畫畫
# 處理 URL: https://app.kolradar.com//kol/e150dff5-2a93-45a8-b071-dafb7c08f36c?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/e150dff5-2a93-45a8-b071-dafb7c08f36c?from=socialAccountRanking', 'kol_name': '馬建豪 Riven Ma®️', 'kol_ig_id': '_hao.0429', 'kol_ig_link': 'https://www.instagram.com/_hao.0429', 'type': '籃球、藝術與娛樂、運動、食譜'}
# 成功插入資料: 馬建豪 Riven Ma®️
# 處理 URL: https://app.kolradar.com//kol/6faf1560-63a9-4ee0-ad2d-2f3311eeaa67?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6faf1560-63a9-4ee0-ad2d-2f3311eeaa67?from=socialAccountRanking', 'kol_name': '馮晨軒 Hsuan Feng', 'kol_ig_id': 'cookiefeng1025', 'kol_ig_link': 'https://www.instagram.com/cookiefeng1025/', 'type': '職場、棒球、藝術與娛樂、美妝時尚、日常話題、命理占卜、運動'}
# 成功插入資料: 馮晨軒 Hsuan Feng
# 處理 URL: https://app.kolradar.com//kol/6698a838-6e43-47e8-a08a-9258bb86f89e?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/6698a838-6e43-47e8-a08a-9258bb86f89e?from=socialAccountRanking', 'kol_name': '高雄點', 'kol_ig_id': 'kaohsiungtien', 'kol_ig_link': 'https://www.instagram.com/kaohsiungtien', 'type': '汽車、日常話題、美食、法政社會'}
# 成功插入資料: 高雄點
# 處理 URL: https://app.kolradar.com//kol/500c2e4c-e2a7-48d4-b782-1a05014a1f36?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/500c2e4c-e2a7-48d4-b782-1a05014a1f36?from=socialAccountRanking', 'kol_name': '吳映潔 GEmma Wu', 'kol_ig_id': 'gemma_811', 'kol_ig_link': 'https://www.instagram.com/gemma_811', 'type': '奢侈品、日常話題、節慶'}
# 成功插入資料: 吳映潔 GEmma Wu
# 處理 URL: https://app.kolradar.com//kol/06b9390a-26bf-4ea0-8b7c-b6eb8502d015?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/06b9390a-26bf-4ea0-8b7c-b6eb8502d015?from=socialAccountRanking', 'kol_name': '蘇志翔', 'kol_ig_id': 'scspple7545', 'kol_ig_link': 'https://www.instagram.com/scspple7545/', 'type': '親子旅遊、日常話題、美食、遊戲、旅遊'}
# 成功插入資料: 蘇志翔
# 處理 URL: https://app.kolradar.com//kol/bf6a52fc-bb49-435d-979e-7fc2e1110af5?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/bf6a52fc-bb49-435d-979e-7fc2e1110af5?from=socialAccountRanking', 'kol_name': '鷹式一家 Queenie &amp; Hiram', 'kol_ig_id': 'zion.zenith', 'kol_ig_link': 'https://www.instagram.com/zion.zenith', 'type': '親子旅遊、教育與學習、家庭、美食、旅遊'}
# 成功插入資料: 鷹式一家 Queenie &amp; Hiram
# 處理 URL: https://app.kolradar.com//kol/a6acd522-d450-4af3-8918-e7ba038db721?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/a6acd522-d450-4af3-8918-e7ba038db721?from=socialAccountRanking', 'kol_name': '麻瓜小兵', 'kol_ig_id': 'minion_muggle', 'kol_ig_link': 'https://www.instagram.com/minion_muggle/', 'type': '台灣旅遊、3C家電、促購導購、田徑、馬拉松、藝術與娛樂、醫療與健康、運動'}
# 成功插入資料: 麻瓜小兵
# 處理 URL: https://app.kolradar.com//kol/63bccdc1-71ea-44e1-a951-aabe77f15ce6?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/63bccdc1-71ea-44e1-a951-aabe77f15ce6?from=socialAccountRanking', 'kol_name': '黃偉哲', 'kol_ig_id': 'weiche946', 'kol_ig_link': 'https://www.instagram.com/weiche946', 'type': '氣候和環境、棒球、法政社會、寵物、運動'}
# 成功插入資料: 黃偉哲
# 處理 URL: https://app.kolradar.com//kol/66fdec22-9c2a-4611-8ee4-11fa0f1f769c?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/66fdec22-9c2a-4611-8ee4-11fa0f1f769c?from=socialAccountRanking', 'kol_name': '黃品甄｜金妮兒𝙅𝙉𝙚𝙖𝙧', 'kol_ig_id': 'hpz.2002', 'kol_ig_link': 'https://www.instagram.com/hpz.2002/', 'type': '舞蹈、藝術與娛樂、穿搭'}
# 成功插入資料: 黃品甄｜金妮兒𝙅𝙉𝙚𝙖𝙧
# 處理 URL: https://app.kolradar.com//kol/4149501b-7813-459e-be00-333a62a03056?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/4149501b-7813-459e-be00-333a62a03056?from=socialAccountRanking', 'kol_name': '黃小柔', 'kol_ig_id': 'huang_roro', 'kol_ig_link': 'https://www.instagram.com/huang_roro/', 'type': '營養與保健、親子旅遊、日常話題、教育與學習、家庭、美食'}
# 成功插入資料: 黃小柔
# 處理 URL: https://app.kolradar.com//kol/b5241707-015b-4beb-8a0c-ba095b1a8263?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/b5241707-015b-4beb-8a0c-ba095b1a8263?from=socialAccountRanking', 'kol_name': '黃昱璇 Lucy', 'kol_ig_id': '_window7', 'kol_ig_link': 'https://www.instagram.com/_window7/', 'type': '電腦遊戲、日常話題、美食、醫療與健康、美髮'}
# 成功插入資料: 黃昱璇 Lucy
# 處理 URL: https://app.kolradar.com//kol/ee137be4-63de-4717-b3d0-b4ba280a9788?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/ee137be4-63de-4717-b3d0-b4ba280a9788?from=socialAccountRanking', 'kol_name': 'Bella大吃貨╰(*´︶`*)╯', 'kol_ig_id': 'bella_eating', 'kol_ig_link': 'https://www.instagram.com/bella_eating/', 'type': '美食、食譜'}
# 成功插入資料: Bella大吃貨╰(*´︶`*)╯
# 處理 URL: https://app.kolradar.com//kol/8079fbf2-a9a2-4402-be72-e0e55eb49c99?from=socialAccountRanking
# 嘗試第 1 次爬取...
# {'kol_link': 'https://app.kolradar.com//kol/8079fbf2-a9a2-4402-be72-e0e55eb49c99?from=socialAccountRanking', 'kol_name': '黃阿瑪的後宮生活', 'kol_ig_id': 'fumeancat', 'kol_ig_link': 'https://www.instagram.com/fumeancat/', 'type': '手機遊戲、救援領養、日常話題、教育與學習、遊戲、寵物'}
# 成功插入資料: 黃阿瑪的後宮生活
# Database connection closed.
