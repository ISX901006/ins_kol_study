# %%
# Section 1: Imports
import time
from datetime import datetime
import re
from DrissionPage import errors
from DrissionPage import ChromiumPage
import mysql.connector
from mysql.connector import Error

def create_connection():
    try:
        connection = mysql.connector.connect(
            host='127.0.0.1',
            database='kol_1017',
            user='root',
            password='123456789',
            port=3306
        )
        if connection.is_connected():
            return connection
    except Error as e:
        print(f"Error while connecting to MySQL: {e}")
    return None

def fetch_instagram_links(connection):
    """Fetch all Instagram links from the kol_radar_info table."""
    try:
        cursor = connection.cursor()
        query = "SELECT kol_ig_link FROM kol_radar_info WHERE kol_ig_link IS NOT NULL"
        cursor.execute(query)
        links = cursor.fetchall()
        return [link[0] for link in links]  # Extract links from tuples
    except Error as e:
        print(f"Error: {e}")
        return []
    finally:
        if cursor:
            cursor.close()

# %%
def fetch_post_links(connection):
    """從 kol_post_data 表中提取所有 post_link 並分類 post 和 reel。"""
    try:
        cursor = connection.cursor()
        query = "SELECT post_link FROM kol_post_data WHERE post_link IS NOT NULL"
        cursor.execute(query)
        links = cursor.fetchall()
        return [link[0] for link in links]  # 提取連結文字
    except Error as e:
        print(f"Error: {e}")
        return []
    finally:
        if cursor:
            cursor.close()

# def fetch_account_id_by_post_link(connection, post_link):
#     """根據 post_link 從 kol_post_data 表中提取 account_id。"""
#     try:
#         cursor = connection.cursor()
#         query = "SELECT account_id FROM kol_post_data WHERE post_link = %s"
#         cursor.execute(query, (post_link,))
#         result = cursor.fetchone()  # 獲取單筆結果
#         return result[0] if result else None  # 如果有結果，返回 account_id，否則返回 None
#     except Error as e:
#         print(f"Error: {e}")
#         return None
#     finally:
#         if cursor:
#             cursor.close()

# import mysql.connector
# from mysql.connector import Error

def fetch_account_id_by_post_link(connection, post_link):
    """根據 post_link 從 kol_post_data 表中提取 account_id，並選擇 likes_count 最大的一筆記錄。"""
    try:
        with connection.cursor() as cursor:  # 確保 cursor 自動關閉
            query = "SELECT account_id, likes_count, comments_count FROM kol_post_data WHERE post_link = %s"
            cursor.execute(query, (post_link,))
            results = cursor.fetchall()  # 取得所有匹配的資料

            if results:
                # 根據 likes_count 選擇最大的一筆結果
                result = max(results)  
                return result[0] if result else None
            else:
                print(f"🔍 No results found for {post_link}")
                return None
    except Error as e:
        print(f"❌ Database Error: {e}")
        return None

    
    
def calculate_post_reel_ratio(links):
    """計算 post 和 reel 的數量及比例。"""
    post_count = sum(1 for link in links if '/p/' in link)
    reel_count = sum(1 for link in links if '/reel/' in link)
    total_count = len(links)

    if total_count == 0:
        return "無法計算比例，因為沒有資料。"

    post_ratio = (post_count / total_count) * 100
    reel_ratio = (reel_count / total_count) * 100

    result = {
        "總數": total_count,
        "Post 數量": post_count,
        "Reel 數量": reel_count,
        "Post 百分比": f"{post_ratio:.2f}%",
        "Reel 百分比": f"{reel_ratio:.2f}%"
    }

    return result

# 實際執行
connection = create_connection()
if connection:
    post_links = fetch_post_links(connection)
    result = calculate_post_reel_ratio(post_links)
    print(result)
    connection.close()
# Out:
# {'總數': 44937, 'Post 數量': 26297, 'Reel 數量': 18640, 'Post 百分比': '58.52%', 'Reel 百分比': '41.48%'}

# %%
def calculate_engagement_rate_by_post_link(connection, post_link):
    """
    根據貼文連結計算該貼文的「按讚數/粉絲數」指標。
    
    Args:
        connection: 資料庫連線物件。
        post_link: 貼文的連結。

    Returns:
        engagement_rate: 該貼文的按讚數/粉絲數比值。如果數據不全，返回 None。
    """
    cursor = None  # 初始化 cursor 變數
    try:
        cursor = connection.cursor()

        # 1. 查詢該貼文的按讚數和留言數及 account_id
        query_post = """
        SELECT likes_count, comments_count, account_id, post_key
        FROM kol_1017.kol_post_data
        WHERE post_link = %s
        """
        cursor.execute(query_post, (post_link,))
        post_data_list = cursor.fetchall()  # 抓取所有匹配的資料

        if not post_data_list:
            print("無法找到該貼文的數據")
            return None

        # 選擇按讚數最高的一筆資料
        post_data = max(post_data_list, key=lambda x: x[0])  # x[0] 是 likes_count

        likes_count, comments_count, account_id, post_key = post_data
        #print(f"likes_count: {likes_count}, comments_count: {comments_count}, account_id: {account_id}")
        # 2. 查詢該發文者的粉絲數
        query_account = """
        SELECT followers_num
        FROM kol_1017.accountinfo
        WHERE account_id = %s
        """
        cursor.execute(query_account, (post_key,))
        account_data = cursor.fetchone()

        if not account_data:
            print("無法找到該發文者的粉絲數")
            return None

        followers_num = account_data[0]

        if followers_num == 0:
            print("粉絲數為 0，無法計算 engagement rate")
            return None

        # 3. 計算 engagement rate (按讚數/粉絲數)
        engagement_rate = likes_count / followers_num

        print(f"按讚數: {likes_count}\n粉絲數: {followers_num}\n互動率 (按讚數/粉絲數): {engagement_rate:.4f}")

        return likes_count, comments_count, followers_num, engagement_rate

    except Error as e:
        print(f"Error: {e}")
        return None
    finally:
        if cursor is not None:
            cursor.close()  # 如果 cursor 被初始化，則關閉

# %%
# connection = create_connection()
# if connection:
#     # 取得所有符合條件的貼文連結
#     post_links = fetch_post_links(connection)
#     post_links = [link for link in post_links if '/p/' in link]
#     # 逐一計算每篇貼文的 engagement rate
#     for post_link in post_links[:1]:
#         calculate_engagement_rate_by_post_link(connection, post_link)

# %% [markdown]
# ## 儲存圖片

# %%
import os
import requests

def save_image_from_url(image_url, file_name, kol_name, base_path='C:\\Users\\SHI\\Desktop\\KOL\\ig_photos'):
    """
    從圖片連結下載圖片並儲存在以 KOL 名稱為資料夾的目錄中。
    
    Args:
        image_url: 圖片的連結 URL。
        file_name: 儲存的檔案名稱（包含副檔名，如 image.jpg）。
        kol_name: KOL 名稱，用於建立子資料夾。
        base_path: 基本的儲存圖片路徑，預設為 'C:\\Users\\SHI\\Desktop\\KOL\\ig_photos'。
    """
    if not image_url:
        print(f"圖片連結無效，無法下載。")
        return
    
    try:
        # 組成 KOL 資料夾路徑
        save_path = os.path.join(base_path, kol_name)
        
        # 確保儲存目錄存在
        os.makedirs(save_path, exist_ok=True)

        # 儲存圖片檔案
        file_path = os.path.join(save_path, file_name)
        response = requests.get(image_url)
        response.raise_for_status()  # 確保請求成功
        with open(file_path, 'wb') as f:
            f.write(response.content)
        
        print(f"圖片已成功儲存至 {file_path}")
    except Exception as e:
        print(f"下載圖片時出現錯誤: {e}")

# %%
def insert_post_data(connection, post_data):
    """
    將貼文資料插入到資料庫的 kol_1017.kol_post_detail 表中。
    
    Args:
        connection: 資料庫連線物件。
        post_data: 字典形式的貼文資料。
    """
    try:
        cursor = connection.cursor()

        # 插入資料的 SQL 語句
        insert_query = """
        INSERT INTO kol_1017.kol_post_detail (post_link, post_id, author, cooperator, article, hashtags, 
                                              product_links, mentions, post_time, image_url, likes_count, followers_count, engagement_rate)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """
        cursor.execute(insert_query, (
            post_data['post_link'], post_data['post_id'], post_data['author'], post_data['cooperator'], post_data['article'],
            post_data['hashtags'], post_data['product_links'], post_data['mentions'], post_data['post_time'], post_data['image_url'],
            post_data['likes_count'], post_data['followers_count'], post_data['engagement_rate']
        ))

        # 提交變更
        connection.commit()
        print(f"貼文資料已成功插入資料庫 (Post ID: {post_data['post_id']})")
    except Exception as e:
        print(f"插入資料時發生錯誤: {e}")
    finally:
        if cursor:
            cursor.close()

def insert_comments(connection, post_id, comments):
    """
    將留言內容插入資料庫的 kol_post_comments 表。

    Args:
        connection: 資料庫連線物件。
        post_id: 貼文的 post_id。
        comments: 留言列表，格式為 [(留言流水號, 留言者 IG ID, 留言內容), ...]。
    """
    try:
        cursor = connection.cursor()

        # 插入留言的 SQL 語句
        insert_query = """
        INSERT INTO kol_1017.kol_post_comments (post_id, comment_id, commenter_id, comment_text)
        VALUES (%s, %s, %s, %s)
        """

        # 插入每一則留言
        for comment_id, commenter_id, comment_text in comments:
            cursor.execute(insert_query, (post_id, comment_id, commenter_id, comment_text))

        # 提交變更
        connection.commit()
        print(f"成功插入 {len(comments)} 則留言到資料庫")
    except Exception as e:
        print(f"插入留言時發生錯誤：{e}")
    finally:
        if cursor:
            cursor.close()

# %% [markdown]
# ##  抓取資料

# %%
from datetime import datetime
import re
import time

def scrape_posts(connection, post_links, start_index, end_index):
    failed_posts = []  # 紀錄未成功的貼文連結和原因
    processed_count = 0  # 計數處理的貼文數量
    rest_interval = 100 # 每處理多少篇貼文後休息
    rest_time =  100

    page = ChromiumPage()

    for link in post_links[start_index:end_index]:
        try:
            page.get(link)
            page.wait(1)

            # 檢查是否為影片
            video_elements = page.eles('.x1lliihq x5yr21d xh8yej3')
            if video_elements:
                print(f"第 {post_links.index(link)+1} 篇貼文是影片，跳過")
                continue
            else:
                print(f"第 {post_links.index(link)+1} 篇貼文")

                post_id = fetch_account_id_by_post_link(connection, link)
                print(f"Post Link: {link}\nPost 編號: {post_id}")

                post_people = page.eles('.x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s x1q0g3np xqjyukv x1cy8zhl x1oa3qoh x1nhvcw1')

                if post_people:
                    kol = post_people[2].text if len(post_people) > 2 else ""  
                    cooperator = post_people[4].text if len(post_people) > 4 else ""  
                else:
                    backup_elements = page.eles('.x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1n2onr6 x1plvlek xryxfnj x1c4vz4f x2lah0s x1q0g3np xqjyukv x6s0dn4 x1oa3qoh x1nhvcw1')
                    kol = backup_elements[0].text if backup_elements else ""  
                    cooperator = ""

                if '\n' in kol:
                    kol = re.sub(r'\n.*$', '', kol).strip()

                post_article_element = page.ele('._ap3a _aaco _aacu _aacx _aad7 _aade')
                post_article = post_article_element.text if post_article_element else ""

                hashtags = ', '.join(sorted(set(re.findall(r'#\w+', post_article))))
                product_links = ', '.join(sorted(set(re.findall(r'https?://\S+', post_article))))
                mentions = ', '.join(sorted(set(re.findall(r'@[a-zA-Z0-9._]+', post_article))))

                post_time = page.ele('.x1p4m5qa', timeout=5).attr('datetime')
                if post_time:
                    try:
                        dt = datetime.strptime(post_time, "%Y-%m-%dT%H:%M:%S.%fZ")
                        post_datetime = dt.strftime("%Y-%m-%d %H:%M:%S")
                    except ValueError:
                        print(f"無法解析日期時間: {post_time}")
                        post_datetime = None

                image = page.ele('.x5yr21d xu96u03 x10l6tqk x13vifvy x87ps6o xh8yej3').attr('src')
                if image:
                    file_name = f"{post_id}.jpg"
                    save_image_from_url(image, file_name, kol)
                likes_count, comments_count, followers_num, engagement_rate = calculate_engagement_rate_by_post_link(connection, link)  
                post_data = {
                    "post_link": link,
                    "post_id": post_id,
                    "author": kol,
                    "cooperator": cooperator,
                    "article": post_article,
                    "hashtags": hashtags,
                    "product_links": product_links,
                    "mentions": mentions,
                    "post_time": post_datetime,
                    "image_url": image,
                    "likes_count": likes_count,
                    "followers_count": followers_num,
                    "engagement_rate": engagement_rate
                }

                insert_post_data(connection, post_data)

                processed_count += 1

                # 每處理到 rest_interval 篇時，休息一段時間
                if processed_count % rest_interval == 0:
                    print(f"🌙 已處理 {processed_count} 篇貼文，休息 {rest_time / 60:.1f} 分鐘...")
                    time.sleep(rest_time)

        except Exception as e:
            post_id = "無法取得貼文編號"
            failed_posts.append((link, str(e)))
            print(f"跳過貼文 {link}，錯誤原因：{e}")

    print(f"共處理 {processed_count} 篇貼文")
    return failed_posts

# %% [markdown]
# 11228開始暫停抓留言

# %%
#呼叫函數
connection = create_connection()
if connection:
    post_links = fetch_post_links(connection)
    post_links = [link for link in post_links if '/p/' in link]

scrape_posts(connection, post_links, 25563, 26500)
# Out:
# 第 25564 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C4pmjycvoSc/
# Post 編號: zrbros_019
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_019.jpg
# 按讚數: 1999
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0444
# 貼文資料已成功插入資料庫 (Post ID: zrbros_019)
# 第 25565 篇貼文是影片，跳過
# 第 25566 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C3eJIQevTX8/
# Post 編號: zrbros_021
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_021.jpg
# 按讚數: 270
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0060
# 貼文資料已成功插入資料庫 (Post ID: zrbros_021)
# 第 25567 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C3dBBn7PVaH/
# Post 編號: zrbros_022
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_022.jpg
# 按讚數: 953
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0212
# 貼文資料已成功插入資料庫 (Post ID: zrbros_022)
# 第 25568 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C3Y07yCvk5l/
# Post 編號: zrbros_024
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_024.jpg
# 按讚數: 312
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0069
# 貼文資料已成功插入資料庫 (Post ID: zrbros_024)
# 第 25569 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C3GDZH3vUXX/
# Post 編號: zrbros_025
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_025.jpg
# 按讚數: 1685
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0374
# 貼文資料已成功插入資料庫 (Post ID: zrbros_025)
# 第 25570 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C2oW3iMP95O/
# Post 編號: zrbros_026
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_026.jpg
# 按讚數: 260
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0058
# 貼文資料已成功插入資料庫 (Post ID: zrbros_026)
# 第 25571 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C2UgfV6ALWg/
# Post 編號: zrbros_027
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_027.jpg
# 按讚數: 163
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0036
# 貼文資料已成功插入資料庫 (Post ID: zrbros_027)
# 第 25572 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C1hbtPtvy7X/
# Post 編號: zrbros_029
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_029.jpg
# 按讚數: 252
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0056
# 貼文資料已成功插入資料庫 (Post ID: zrbros_029)
# 第 25573 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C1ZAaPSPlIV/
# Post 編號: zrbros_031
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_031.jpg
# 按讚數: 691
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0154
# 貼文資料已成功插入資料庫 (Post ID: zrbros_031)
# 第 25574 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C0y9tnIP6bB/
# Post 編號: zrbros_032
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_032.jpg
# 按讚數: 694
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0154
# 貼文資料已成功插入資料庫 (Post ID: zrbros_032)
# 第 25575 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C0y8-Mlvqeo/
# Post 編號: zrbros_033
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_033.jpg
# 按讚數: 194
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0043
# 貼文資料已成功插入資料庫 (Post ID: zrbros_033)
# 第 25576 篇貼文是影片，跳過
# 第 25577 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C0EqEsVPVzu/
# Post 編號: zrbros_035
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_035.jpg
# 按讚數: 680
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0151
# 貼文資料已成功插入資料庫 (Post ID: zrbros_035)
# 第 25578 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C0EmCVfvIxk/
# Post 編號: zrbros_036
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_036.jpg
# 按讚數: 1119
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0249
# 貼文資料已成功插入資料庫 (Post ID: zrbros_036)
# 第 25579 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/C0ElByWvVrZ/
# Post 編號: zrbros_037
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_037.jpg
# 按讚數: 728
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0162
# 貼文資料已成功插入資料庫 (Post ID: zrbros_037)
# 第 25580 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CzOU8KdPVSa/
# Post 編號: zrbros_038
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_038.jpg
# 按讚數: 200
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0044
# 貼文資料已成功插入資料庫 (Post ID: zrbros_038)
# 第 25581 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CyK_EjGu5H6/
# Post 編號: zrbros_039
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_039.jpg
# 按讚數: 564
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0125
# 貼文資料已成功插入資料庫 (Post ID: zrbros_039)
# 第 25582 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cwg5Ix6vIHt/
# Post 編號: zrbros_040
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_040.jpg
# 按讚數: 240
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0053
# 貼文資料已成功插入資料庫 (Post ID: zrbros_040)
# 第 25583 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CvcZoNjPXPB/
# Post 編號: zrbros_042
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_042.jpg
# 按讚數: 1787
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0397
# 貼文資料已成功插入資料庫 (Post ID: zrbros_042)
# 第 25584 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cutln3eONA5/
# Post 編號: zrbros_043
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_043.jpg
# 按讚數: 786
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0175
# 貼文資料已成功插入資料庫 (Post ID: zrbros_043)
# 第 25585 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CumwdtcO100/
# Post 編號: zrbros_044
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_044.jpg
# 按讚數: 369
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0082
# 貼文資料已成功插入資料庫 (Post ID: zrbros_044)
# 第 25586 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Ctl_rVYu0wK/
# Post 編號: zrbros_045
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_045.jpg
# 按讚數: 67
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0015
# 貼文資料已成功插入資料庫 (Post ID: zrbros_045)
# 第 25587 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CtbYO9OPov0/
# Post 編號: zrbros_046
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_046.jpg
# 按讚數: 129
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0029
# 貼文資料已成功插入資料庫 (Post ID: zrbros_046)
# 第 25588 篇貼文是影片，跳過
# 第 25589 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CtO9SVcPB_y/
# Post 編號: zrbros_048
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_048.jpg
# 按讚數: 429
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0095
# 貼文資料已成功插入資料庫 (Post ID: zrbros_048)
# 第 25590 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CtMdbwxPozP/
# Post 編號: zrbros_049
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_049.jpg
# 按讚數: 311
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0069
# 貼文資料已成功插入資料庫 (Post ID: zrbros_049)
# 第 25591 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CtKGvmjvvDI/
# Post 編號: zrbros_050
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_050.jpg
# 按讚數: 292
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0065
# 貼文資料已成功插入資料庫 (Post ID: zrbros_050)
# 第 25592 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CtCNDAjPX97/
# Post 編號: zrbros_051
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_051.jpg
# 按讚數: 455
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0101
# 貼文資料已成功插入資料庫 (Post ID: zrbros_051)
# 第 25593 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cs_T3uHv-fl/
# Post 編號: zrbros_052
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_052.jpg
# 按讚數: 382
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0085
# 貼文資料已成功插入資料庫 (Post ID: zrbros_052)
# 第 25594 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cs-uuf3OKnT/
# Post 編號: zrbros_053
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_053.jpg
# 按讚數: 371
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0082
# 貼文資料已成功插入資料庫 (Post ID: zrbros_053)
# 第 25595 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cs8aVD_vObw/
# Post 編號: zrbros_054
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_054.jpg
# 按讚數: 299
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0066
# 貼文資料已成功插入資料庫 (Post ID: zrbros_054)
# 第 25596 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cs6X7j2vvV9/
# Post 編號: zrbros_055
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_055.jpg
# 按讚數: 815
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0181
# 貼文資料已成功插入資料庫 (Post ID: zrbros_055)
# 第 25597 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cs4zBBrh59Q/
# Post 編號: zrbros_056
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_056.jpg
# 按讚數: 936
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0208
# 貼文資料已成功插入資料庫 (Post ID: zrbros_056)
# 第 25598 篇貼文是影片，跳過
# 第 25599 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cs012ehPZDu/
# Post 編號: zrbros_058
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_058.jpg
# 按讚數: 936
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0208
# 貼文資料已成功插入資料庫 (Post ID: zrbros_058)
# 第 25600 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CsyYi7ZvMNS/
# Post 編號: zrbros_059
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_059.jpg
# 按讚數: 992
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0220
# 貼文資料已成功插入資料庫 (Post ID: zrbros_059)
# 第 25601 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CsOfQxcPg_q/
# Post 編號: zrbros_060
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_060.jpg
# 按讚數: 1606
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0357
# 貼文資料已成功插入資料庫 (Post ID: zrbros_060)
# 第 25602 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CrJGMTEvb9Q/
# Post 編號: zrbros_061
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_061.jpg
# 按讚數: 162
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0036
# 貼文資料已成功插入資料庫 (Post ID: zrbros_061)
# 第 25603 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CquFZlXv0nd/
# Post 編號: zrbros_062
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_062.jpg
# 按讚數: 249
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0055
# 貼文資料已成功插入資料庫 (Post ID: zrbros_062)
# 第 25604 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CqVJkMrvGF1/
# Post 編號: zrbros_063
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_063.jpg
# 按讚數: 805
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0179
# 貼文資料已成功插入資料庫 (Post ID: zrbros_063)
# 第 25605 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CqR4QEXvn2P/
# Post 編號: zrbros_064
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_064.jpg
# 按讚數: 171
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0038
# 貼文資料已成功插入資料庫 (Post ID: zrbros_064)
# 第 25606 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CpXCuHfuAnE/
# Post 編號: zrbros_065
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_065.jpg
# 按讚數: 244
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0054
# 貼文資料已成功插入資料庫 (Post ID: zrbros_065)
# 第 25607 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Co_MvomOK85/
# Post 編號: zrbros_066
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_066.jpg
# 按讚數: 267
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0059
# 貼文資料已成功插入資料庫 (Post ID: zrbros_066)
# 第 25608 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CnspD9KPmTs/
# Post 編號: zrbros_067
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_067.jpg
# 按讚數: 381
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0085
# 貼文資料已成功插入資料庫 (Post ID: zrbros_067)
# 第 25609 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cnn2BSfPmii/
# Post 編號: zrbros_068
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_068.jpg
# 按讚數: 1200
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0267
# 貼文資料已成功插入資料庫 (Post ID: zrbros_068)
# 第 25610 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cnb3D9vvkPE/
# Post 編號: zrbros_069
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_069.jpg
# 按讚數: 188
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0042
# 貼文資料已成功插入資料庫 (Post ID: zrbros_069)
# 第 25611 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CnOjRbquSz7/
# Post 編號: zrbros_070
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_070.jpg
# 按讚數: 487
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0108
# 貼文資料已成功插入資料庫 (Post ID: zrbros_070)
# 第 25612 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CnMCF0MJ6g3/
# Post 編號: zrbros_071
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_071.jpg
# 按讚數: 164
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0036
# 貼文資料已成功插入資料庫 (Post ID: zrbros_071)
# 第 25613 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CnHd5RdvD_-/
# Post 編號: zrbros_073
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_073.jpg
# 按讚數: 135
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0030
# 貼文資料已成功插入資料庫 (Post ID: zrbros_073)
# 第 25614 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CnD40LVvz6M/
# Post 編號: zrbros_074
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_074.jpg
# 按讚數: 426
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0095
# 貼文資料已成功插入資料庫 (Post ID: zrbros_074)
# 第 25615 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cm-Odo-rzi6/
# Post 編號: zrbros_075
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_075.jpg
# 按讚數: 250
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0056
# 貼文資料已成功插入資料庫 (Post ID: zrbros_075)
# 第 25616 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CmtSW1_OKmE/
# Post 編號: zrbros_076
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_076.jpg
# 按讚數: 337
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0075
# 貼文資料已成功插入資料庫 (Post ID: zrbros_076)
# 第 25617 篇貼文是影片，跳過
# 第 25618 篇貼文是影片，跳過
# 第 25619 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cl3v6Bapacs/
# Post 編號: zrbros_080
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_080.jpg
# 按讚數: 1013
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0225
# 貼文資料已成功插入資料庫 (Post ID: zrbros_080)
# 第 25620 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cl0RHSTPkK_/
# Post 編號: zrbros_081
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_081.jpg
# 按讚數: 116
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0026
# 貼文資料已成功插入資料庫 (Post ID: zrbros_081)
# 第 25621 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cl0Phx3v4dS/
# Post 編號: zrbros_082
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_082.jpg
# 按讚數: 222
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0049
# 貼文資料已成功插入資料庫 (Post ID: zrbros_082)
# 第 25622 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Clr5n0LvFWh/
# Post 編號: zrbros_083
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_083.jpg
# 按讚數: 221
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0049
# 貼文資料已成功插入資料庫 (Post ID: zrbros_083)
# 第 25623 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Cllv5TMvVi0/
# Post 編號: zrbros_084
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_084.jpg
# 按讚數: 220
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0049
# 貼文資料已成功插入資料庫 (Post ID: zrbros_084)
# 第 25624 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/CllhGMmvFjK/
# Post 編號: zrbros_085
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_085.jpg
# 按讚數: 165
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0037
# 貼文資料已成功插入資料庫 (Post ID: zrbros_085)
# 第 25625 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClfutPPvEs6/
# Post 編號: zrbros_086
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_086.jpg
# 按讚數: 259
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0058
# 貼文資料已成功插入資料庫 (Post ID: zrbros_086)
# 第 25626 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClfsvfhPPFi/
# Post 編號: zrbros_087
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_087.jpg
# 按讚數: 131
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0029
# 貼文資料已成功插入資料庫 (Post ID: zrbros_087)
# 第 25627 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClZqsaBhaFp/
# Post 編號: zrbros_088
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_088.jpg
# 按讚數: 164
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0036
# 貼文資料已成功插入資料庫 (Post ID: zrbros_088)
# 第 25628 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClZFg9-PIAj/
# Post 編號: zrbros_089
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_089.jpg
# 按讚數: 137
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0030
# 貼文資料已成功插入資料庫 (Post ID: zrbros_089)
# 第 25629 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClWbAjFPcAm/
# Post 編號: zrbros_090
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_090.jpg
# 按讚數: 136
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0030
# 貼文資料已成功插入資料庫 (Post ID: zrbros_090)
# 第 25630 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClTKcNdvPvq/
# Post 編號: zrbros_091
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_091.jpg
# 按讚數: 152
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0034
# 貼文資料已成功插入資料庫 (Post ID: zrbros_091)
# 第 25631 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClPC2prBnW-/
# Post 編號: zrbros_092
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_092.jpg
# 按讚數: 278
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0062
# 貼文資料已成功插入資料庫 (Post ID: zrbros_092)
# 第 25632 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClOg_iZPJuP/
# Post 編號: zrbros_093
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_093.jpg
# 按讚數: 106
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0024
# 貼文資料已成功插入資料庫 (Post ID: zrbros_093)
# 第 25633 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClKo5CXvkLj/
# Post 編號: zrbros_094
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_094.jpg
# 按讚數: 134
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0030
# 貼文資料已成功插入資料庫 (Post ID: zrbros_094)
# 第 25634 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClHLkqNvMl8/
# Post 編號: zrbros_095
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_095.jpg
# 按讚數: 127
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0028
# 貼文資料已成功插入資料庫 (Post ID: zrbros_095)
# 第 25635 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClEHm6CPhPC/
# Post 編號: zrbros_096
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_096.jpg
# 按讚數: 140
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0031
# 貼文資料已成功插入資料庫 (Post ID: zrbros_096)
# 第 25636 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/ClBsAGDvZHq/
# Post 編號: zrbros_097
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_097.jpg
# 按讚數: 246
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0055
# 貼文資料已成功插入資料庫 (Post ID: zrbros_097)
# 第 25637 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Ck-gtO3OiNe/
# Post 編號: zrbros_098
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_098.jpg
# 按讚數: 173
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0038
# 貼文資料已成功插入資料庫 (Post ID: zrbros_098)
# 第 25638 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Ck9bn7UhQ1v/
# Post 編號: zrbros_099
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_099.jpg
# 按讚數: 128
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0028
# 貼文資料已成功插入資料庫 (Post ID: zrbros_099)
# 第 25639 篇貼文
# Post Link: https://www.instagram.com/zrbros/p/Ck64mAZhoKg/
# Post 編號: zrbros_100
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\zrbros\zrbros_100.jpg
# 按讚數: 158
# 粉絲數: 45000
# 互動率 (按讚數/粉絲數): 0.0035
# 貼文資料已成功插入資料庫 (Post ID: zrbros_100)
# 第 25640 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DEcZOOIo8bq/
# Post 編號: ping7446_002
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_002.jpg
# 按讚數: 16000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0166
# 貼文資料已成功插入資料庫 (Post ID: ping7446_002)
# 第 25641 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DEPUhv7o_yi/
# Post 編號: ping7446_005
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_005.jpg
# 按讚數: 14000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0145
# 貼文資料已成功插入資料庫 (Post ID: ping7446_005)
# 第 25642 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DEH8q6utN8w/
# Post 編號: ping7446_008
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_008.jpg
# 按讚數: 12000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0124
# 貼文資料已成功插入資料庫 (Post ID: ping7446_008)
# 第 25643 篇貼文是影片，跳過
# 第 25644 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DD9EM52u80C/
# Post 編號: ping7446_013
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_013.jpg
# 按讚數: 17000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0176
# 貼文資料已成功插入資料庫 (Post ID: ping7446_013)
# 第 25645 篇貼文是影片，跳過
# 第 25646 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DDtzmP8uodi/
# Post 編號: ping7446_019
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_019.jpg
# 按讚數: 8825
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0091
# 貼文資料已成功插入資料庫 (Post ID: ping7446_019)
# 第 25647 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DDmDBzeOttr/
# Post 編號: ping7446_020
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_020.jpg
# 按讚數: 10000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0104
# 貼文資料已成功插入資料庫 (Post ID: ping7446_020)
# 第 25648 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DDjUFyRODpE/
# Post 編號: ping7446_021
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_021.jpg
# 按讚數: 21000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0217
# 貼文資料已成功插入資料庫 (Post ID: ping7446_021)
# 第 25649 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DDcFfCKosPk/
# Post 編號: ping7446_023
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_023.jpg
# 按讚數: 13000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0135
# 貼文資料已成功插入資料庫 (Post ID: ping7446_023)
# 第 25650 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DDUC2gyubrJ/
# Post 編號: ping7446_025
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_025.jpg
# 按讚數: 9872
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0102
# 貼文資料已成功插入資料庫 (Post ID: ping7446_025)
# 第 25651 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DDJlmJ4u-xT/
# Post 編號: ping7446_027
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_027.jpg
# 按讚數: 5278
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0055
# 貼文資料已成功插入資料庫 (Post ID: ping7446_027)
# 第 25652 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DCoVcmitZYG/
# Post 編號: ping7446_031
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_031.jpg
# 按讚數: 21000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0217
# 貼文資料已成功插入資料庫 (Post ID: ping7446_031)
# 第 25653 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DClv-DvOtEn/
# Post 編號: ping7446_032
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_032.jpg
# 按讚數: 15000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0155
# 貼文資料已成功插入資料庫 (Post ID: ping7446_032)
# 第 25654 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DCeXOyhIP9N/
# Post 編號: ping7446_034
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_034.jpg
# 按讚數: 9554
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0099
# 貼文資料已成功插入資料庫 (Post ID: ping7446_034)
# 第 25655 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DCd0uxeO7rB/
# Post 編號: ping7446_035
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_035.jpg
# 按讚數: 9474
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0098
# 貼文資料已成功插入資料庫 (Post ID: ping7446_035)
# 第 25656 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DCY3s13OOSN/
# Post 編號: ping7446_036
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_036.jpg
# 按讚數: 5882
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0061
# 貼文資料已成功插入資料庫 (Post ID: ping7446_036)
# 第 25657 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DCUJKfhNFtZ/
# Post 編號: ping7446_038
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_038.jpg
# 按讚數: 8991
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0093
# 貼文資料已成功插入資料庫 (Post ID: ping7446_038)
# 第 25658 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DCEWx_1tDYJ/
# Post 編號: ping7446_041
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_041.jpg
# 按讚數: 9890
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0102
# 貼文資料已成功插入資料庫 (Post ID: ping7446_041)
# 第 25659 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DBi7MWENps9/
# Post 編號: ping7446_046
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_046.jpg
# 按讚數: 26000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0269
# 貼文資料已成功插入資料庫 (Post ID: ping7446_046)
# 第 25660 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DBWA1-NO716/
# Post 編號: ping7446_050
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_050.jpg
# 按讚數: 11000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0114
# 貼文資料已成功插入資料庫 (Post ID: ping7446_050)
# 第 25661 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DBLJRWFov-J/
# Post 編號: ping7446_052
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_052.jpg
# 按讚數: 3118
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0032
# 貼文資料已成功插入資料庫 (Post ID: ping7446_052)
# 第 25662 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DBD0MZZuxU6/
# Post 編號: ping7446_053
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_053.jpg
# 按讚數: 14000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0145
# 貼文資料已成功插入資料庫 (Post ID: ping7446_053)
# 第 25663 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DA8jHKEonbA/
# Post 編號: ping7446_054
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_054.jpg
# 按讚數: 20000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0207
# 貼文資料已成功插入資料庫 (Post ID: ping7446_054)
# 第 25664 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DA5Xgl2uH7G/
# Post 編號: ping7446_055
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_055.jpg
# 按讚數: 18000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0186
# 貼文資料已成功插入資料庫 (Post ID: ping7446_055)
# 第 25665 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DA2tWREODxV/
# Post 編號: ping7446_056
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_056.jpg
# 按讚數: 20000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0207
# 貼文資料已成功插入資料庫 (Post ID: ping7446_056)
# 第 25666 篇貼文是影片，跳過
# 第 25667 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DAa4e90o4JA/
# Post 編號: ping7446_061
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_061.jpg
# 按讚數: 16000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0166
# 貼文資料已成功插入資料庫 (Post ID: ping7446_061)
# 第 25668 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DAXrQDno5o2/
# Post 編號: ping7446_062
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_062.jpg
# 按讚數: 1911
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0020
# 貼文資料已成功插入資料庫 (Post ID: ping7446_062)
# 第 25669 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/DASvU9sOgc-/
# Post 編號: ping7446_065
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_065.jpg
# 按讚數: 20000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0207
# 貼文資料已成功插入資料庫 (Post ID: ping7446_065)
# 第 25670 篇貼文是影片，跳過
# 第 25671 篇貼文是影片，跳過
# 第 25672 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/C_cnx1-uFUK/
# Post 編號: ping7446_072
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_072.jpg
# 按讚數: 13000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0135
# 貼文資料已成功插入資料庫 (Post ID: ping7446_072)
# 第 25673 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/C_Ko9GnO7wM/
# Post 編號: ping7446_075
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_075.jpg
# 按讚數: 51000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0528
# 貼文資料已成功插入資料庫 (Post ID: ping7446_075)
# 第 25674 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/C_AZELuuJtY/
# Post 編號: ping7446_078
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_078.jpg
# 按讚數: 14000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0145
# 貼文資料已成功插入資料庫 (Post ID: ping7446_078)
# 🌙 已處理 100 篇貼文，休息 1.7 分鐘...
# 第 25675 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/C-10JFKS1AP/
# Post 編號: ping7446_081
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_081.jpg
# 按讚數: 18000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0186
# 貼文資料已成功插入資料庫 (Post ID: ping7446_081)
# 第 25676 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/C-rP0ZHy0zm/
# Post 編號: ping7446_084
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_084.jpg
# 按讚數: 15000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0155
# 貼文資料已成功插入資料庫 (Post ID: ping7446_084)
# 第 25677 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/C-mzM-5S0_y/
# Post 編號: ping7446_086
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_086.jpg
# 按讚數: 24000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0248
# 貼文資料已成功插入資料庫 (Post ID: ping7446_086)
# 第 25678 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/C-XjZvQyB8v/
# Post 編號: ping7446_090
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_090.jpg
# 按讚數: 2160
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0022
# 貼文資料已成功插入資料庫 (Post ID: ping7446_090)
# 第 25679 篇貼文
# Post Link: https://www.instagram.com/ping7446/p/C-EgtjKSApM/
# Post 編號: ping7446_095
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\ping7446\ping7446_095.jpg
# 按讚數: 24000
# 粉絲數: 966000
# 互動率 (按讚數/粉絲數): 0.0248
# 貼文資料已成功插入資料庫 (Post ID: ping7446_095)
# 第 25680 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DEhCA1CSO7g/
# Post 編號: nanaciaociao_001
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_001.jpg
# 按讚數: 6143
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0114
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_001)
# 第 25681 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DEWiO4JS-_-/
# Post 編號: nanaciaociao_004
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_004.jpg
# 按讚數: 6454
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0119
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_004)
# 第 25682 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DEQAhvHy4s8/
# Post 編號: nanaciaociao_005
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_005.jpg
# 按讚數: 5665
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0105
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_005)
# 第 25683 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DD_vZJYSrbd/
# Post 編號: nanaciaociao_010
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_010.jpg
# 按讚數: 8996
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0166
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_010)
# 第 25684 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DD9XzGFS-j9/
# Post 編號: nanaciaociao_011
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_011.jpg
# 按讚數: 4948
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0091
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_011)
# 第 25685 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DD07mjFzcFw/
# Post 編號: nanaciaociao_013
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_013.jpg
# 按讚數: 10000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0185
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_013)
# 第 25686 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DDwV7G5SFHJ/
# Post 編號: nanaciaociao_014
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_014.jpg
# 按讚數: 15000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0277
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_014)
# 第 25687 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DDgVS5jTYq-/
# Post 編號: nanaciaociao_018
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_018.jpg
# 按讚數: 33000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0610
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_018)
# 第 25688 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DDUK_-kyZb8/
# Post 編號: nanaciaociao_019
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_019.jpg
# 按讚數: 14000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0259
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_019)
# 第 25689 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DDBbwX6SvJC/
# Post 編號: nanaciaociao_024
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_024.jpg
# 按讚數: 9868
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0182
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_024)
# 第 25690 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DC_BOhTzdu1/
# Post 編號: nanaciaociao_025
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_025.jpg
# 按讚數: 4649
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0086
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_025)
# 第 25691 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DCqQm8NSYdJ/
# Post 編號: nanaciaociao_027
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_027.jpg
# 按讚數: 8232
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0152
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_027)
# 第 25692 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DCGRf8ZJAJi/
# Post 編號: nanaciaociao_029
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_029.jpg
# 按讚數: 15000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0277
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_029)
# 第 25693 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DCTCaqeSFT3/
# Post 編號: nanaciaociao_032
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_032.jpg
# 按讚數: 10000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0185
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_032)
# 第 25694 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DCQ_ip4yx81/
# Post 編號: nanaciaociao_033
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_033.jpg
# 按讚數: 7585
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0140
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_033)
# 第 25695 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DCQhOPjJlWD/
# Post 編號: nanaciaociao_035
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_035.jpg
# 按讚數: 6771
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0125
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_035)
# 第 25696 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DCIyPTZSCww/
# Post 編號: nanaciaociao_036
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_036.jpg
# 按讚數: 13000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0240
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_036)
# 第 25697 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DCDq8kGJi9r/
# Post 編號: nanaciaociao_037
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_037.jpg
# 按讚數: 15000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0277
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_037)
# 第 25698 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DCLV32FJKfP/
# Post 編號: nanaciaociao_039
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_039.jpg
# 按讚數: 30000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0555
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_039)
# 第 25699 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DBlohJCST5R/
# Post 編號: nanaciaociao_046
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_046.jpg
# 按讚數: 6147
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0114
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_046)
# 第 25700 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DBc9U0YSn6b/
# Post 編號: nanaciaociao_049
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_049.jpg
# 按讚數: 6911
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0128
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_049)
# 第 25701 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DBYPNjLygWG/
# Post 編號: nanaciaociao_051
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_051.jpg
# 按讚數: 14000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0259
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_051)
# 第 25702 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DBNyXWSy6K_/
# Post 編號: nanaciaociao_053
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_053.jpg
# 按讚數: 6681
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0123
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_053)
# 第 25703 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DBIyyu2ygDB/
# Post 編號: nanaciaociao_054
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_054.jpg
# 按讚數: 7448
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0138
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_054)
# 第 25704 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DAuqbADOOKI/
# Post 編號: nanaciaociao_059
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_059.jpg
# 按讚數: 9414
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0174
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_059)
# 第 25705 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DAqDuicyaRN/
# Post 編號: nanaciaociao_061
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_061.jpg
# 按讚數: 11000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0203
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_061)
# 第 25706 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DAk7zdBy021/
# Post 編號: nanaciaociao_062
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_062.jpg
# 按讚數: 8798
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0163
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_062)
# 第 25707 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DAaEsDGSF4h/
# Post 編號: nanaciaociao_064
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_064.jpg
# 按讚數: 22000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0407
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_064)
# 第 25708 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DAP7Ir3y4cO/
# Post 編號: nanaciaociao_066
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_066.jpg
# 按讚數: 12000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0222
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_066)
# 第 25709 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/DAKzV9sSZnS/
# Post 編號: nanaciaociao_068
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_068.jpg
# 按讚數: 29000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0536
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_068)
# 第 25710 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C_2ZkepyeSo/
# Post 編號: nanaciaociao_070
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_070.jpg
# 按讚數: 10000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0185
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_070)
# 第 25711 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C_pdvdPy3ty/
# Post 編號: nanaciaociao_074
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_074.jpg
# 按讚數: 10000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0185
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_074)
# 第 25712 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C_UqFDbyE4E/
# Post 編號: nanaciaociao_076
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_076.jpg
# 按讚數: 13000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0240
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_076)
# 第 25713 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C_R9zYySO-M/
# Post 編號: nanaciaociao_078
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_078.jpg
# 按讚數: 16000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0296
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_078)
# 第 25714 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C_IJiAOy4fb/
# Post 編號: nanaciaociao_080
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_080.jpg
# 按讚數: 7880
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0146
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_080)
# 第 25715 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C-7YY1Kyqe1/
# Post 編號: nanaciaociao_084
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_084.jpg
# 按讚數: 11000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0203
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_084)
# 第 25716 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C-4V5GSysYb/
# Post 編號: nanaciaociao_085
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_085.jpg
# 按讚數: 9574
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0177
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_085)
# 第 25717 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C-zHtN4Sn_1/
# Post 編號: nanaciaociao_086
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_086.jpg
# 按讚數: 50000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0924
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_086)
# 第 25718 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C-b1KFEyI3c/
# Post 編號: nanaciaociao_092
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_092.jpg
# 按讚數: 4798
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0089
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_092)
# 第 25719 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C-KAociSvYv/
# Post 編號: nanaciaociao_094
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_094.jpg
# 按讚數: 8187
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0151
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_094)
# 第 25720 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C-E4QOwSIfZ/
# Post 編號: nanaciaociao_095
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_095.jpg
# 按讚數: 10000
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0185
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_095)
# 第 25721 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C9xaomGyuOS/
# Post 編號: nanaciaociao_098
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_098.jpg
# 按讚數: 7612
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0141
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_098)
# 第 25722 篇貼文
# Post Link: https://www.instagram.com/nanaciaociao/p/C9t645CShN_/
# Post 編號: nanaciaociao_100
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\nanaciaociao\nanaciaociao_100.jpg
# 按讚數: 6761
# 粉絲數: 541000
# 互動率 (按讚數/粉絲數): 0.0125
# 貼文資料已成功插入資料庫 (Post ID: nanaciaociao_100)
# 第 25723 篇貼文
# Post Link: https://www.instagram.com/rosalina.kitchen/p/C-kir9EKfik/
# Post 編號: rosalina.kitchen_045
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\rosalina.kitchen\rosalina.kitchen_045.jpg
# 按讚數: 1471
# 粉絲數: 118000
# 互動率 (按讚數/粉絲數): 0.0125
# 貼文資料已成功插入資料庫 (Post ID: rosalina.kitchen_045)
# 第 25724 篇貼文
# Post Link: https://www.instagram.com/rosalina.kitchen/p/C8cKmGpBNdC/
# Post 編號: rosalina.kitchen_070
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\rosalina.kitchen\rosalina.kitchen_070.jpg
# 按讚數: 676
# 粉絲數: 118000
# 互動率 (按讚數/粉絲數): 0.0057
# 貼文資料已成功插入資料庫 (Post ID: rosalina.kitchen_070)
# 第 25725 篇貼文
# Post Link: https://www.instagram.com/rosalina.kitchen/p/C7O02CIt3nb/
# Post 編號: rosalina.kitchen_082
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\rosalina.kitchen\rosalina.kitchen_082.jpg
# 按讚數: 563
# 粉絲數: 118000
# 互動率 (按讚數/粉絲數): 0.0048
# 貼文資料已成功插入資料庫 (Post ID: rosalina.kitchen_082)
# 第 25726 篇貼文
# Post Link: https://www.instagram.com/rosalina.kitchen/p/C6LprjTLhB9/
# Post 編號: rosalina.kitchen_092
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\rosalina.kitchen\rosalina.kitchen_092.jpg
# 按讚數: 125
# 粉絲數: 118000
# 互動率 (按讚數/粉絲數): 0.0011
# 貼文資料已成功插入資料庫 (Post ID: rosalina.kitchen_092)
# 第 25727 篇貼文
# Post Link: https://www.instagram.com/rosalina.kitchen/p/C5iqfLgMS9V/
# Post 編號: rosalina.kitchen_096
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\rosalina.kitchen\rosalina.kitchen_096.jpg
# 按讚數: 432
# 粉絲數: 118000
# 互動率 (按讚數/粉絲數): 0.0037
# 貼文資料已成功插入資料庫 (Post ID: rosalina.kitchen_096)
# 第 25728 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DERbA4dzjyZ/
# Post 編號: pt_motodaily_001
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_001.jpg
# 按讚數: 374
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0080
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_001)
# 第 25729 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DENG_buyvH3/
# Post 編號: pt_motodaily_002
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_002.jpg
# 按讚數: 590
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0126
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_002)
# 第 25730 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DD_YPz0TBkD/
# Post 編號: pt_motodaily_005
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_005.jpg
# 按讚數: 930
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0198
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_005)
# 第 25731 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DD7NnJ3z6Hv/
# Post 編號: pt_motodaily_006
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_006.jpg
# 按讚數: 1204
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0256
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_006)
# 第 25732 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDzl3v9Trmw/
# Post 編號: pt_motodaily_007
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_007.jpg
# 按讚數: 936
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0199
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_007)
# 第 25733 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDvmnO8he1H/
# Post 編號: pt_motodaily_008
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_008.jpg
# 按讚數: 1317
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0280
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_008)
# 第 25734 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDlsXoFBLLR/
# Post 編號: pt_motodaily_009
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_009.jpg
# 按讚數: 731
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0156
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_009)
# 第 25735 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDhgWD2htAk/
# Post 編號: pt_motodaily_010
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_010.jpg
# 按讚數: 1349
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0287
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_010)
# 第 25736 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDcd4hdTfS3/
# Post 編號: pt_motodaily_011
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_011.jpg
# 按讚數: 1016
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0216
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_011)
# 第 25737 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDPnsFCTRQj/
# Post 編號: pt_motodaily_012
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_012.jpg
# 按讚數: 870
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0185
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_012)
# 第 25738 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDOEFzFyaUC/
# Post 編號: pt_motodaily_013
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_013.jpg
# 按讚數: 858
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0183
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_013)
# 第 25739 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDLU3HYz5RV/
# Post 編號: pt_motodaily_014
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_014.jpg
# 按讚數: 1483
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0316
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_014)
# 第 25740 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDHHTeWz4qG/
# Post 編號: pt_motodaily_015
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_015.jpg
# 按讚數: 1208
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0257
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_015)
# 第 25741 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DDFX6gXhd8a/
# Post 編號: pt_motodaily_016
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_016.jpg
# 按讚數: 2132
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0454
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_016)
# 第 25742 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DC1hARvzYkm/
# Post 編號: pt_motodaily_017
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_017.jpg
# 按讚數: 1117
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0238
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_017)
# 第 25743 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DCjqBNwTFlb/
# Post 編號: pt_motodaily_018
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_018.jpg
# 按讚數: 812
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0173
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_018)
# 第 25744 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DCOoW1jyXGV/
# Post 編號: pt_motodaily_019
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_019.jpg
# 按讚數: 794
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0169
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_019)
# 第 25745 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DCE6KNhTJtZ/
# Post 編號: pt_motodaily_020
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_020.jpg
# 按讚數: 1372
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0292
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_020)
# 第 25746 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DBuBBxQzGXR/
# Post 編號: pt_motodaily_021
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_021.jpg
# 按讚數: 645
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0137
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_021)
# 第 25747 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DBpxaQzzI87/
# Post 編號: pt_motodaily_023
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_023.jpg
# 按讚數: 1128
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0240
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_023)
# 第 25748 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DBg5i6fSG9y/
# Post 編號: pt_motodaily_024
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_024.jpg
# 按讚數: 988
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0210
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_024)
# 第 25749 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DBdGHVvz2tO/
# Post 編號: pt_motodaily_025
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_025.jpg
# 按讚數: 3331
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0709
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_025)
# 第 25750 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DBXnccaSyzR/
# Post 編號: pt_motodaily_026
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_026.jpg
# 按讚數: 1192
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0254
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_026)
# 第 25751 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DBU82FszxfI/
# Post 編號: pt_motodaily_027
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_027.jpg
# 按讚數: 1268
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0270
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_027)
# 第 25752 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DBNNxKsTwvf/
# Post 編號: pt_motodaily_029
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_029.jpg
# 按讚數: 1319
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0281
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_029)
# 第 25753 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DA4lVsDTNQP/
# Post 編號: pt_motodaily_031
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_031.jpg
# 按讚數: 1200
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0255
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_031)
# 第 25754 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DAmrhawzn7S/
# Post 編號: pt_motodaily_032
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_032.jpg
# 按讚數: 1091
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0232
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_032)
# 第 25755 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DAakeNfz3sM/
# Post 編號: pt_motodaily_034
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_034.jpg
# 按讚數: 675
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0144
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_034)
# 第 25756 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/DABDQgfSBAN/
# Post 編號: pt_motodaily_035
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_035.jpg
# 按讚數: 1424
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0303
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_035)
# 第 25757 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/C_VPjWgyAR1/
# Post 編號: pt_motodaily_036
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_036.jpg
# 按讚數: 846
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0180
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_036)
# 第 25758 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/C--hL0RyUNr/
# Post 編號: pt_motodaily_038
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_038.jpg
# 按讚數: 913
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0194
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_038)
# 第 25759 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/C-Y_0FHSw2R/
# Post 編號: pt_motodaily_040
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_040.jpg
# 按讚數: 1131
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0241
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_040)
# 第 25760 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/C-HWLWFSHGd/
# Post 編號: pt_motodaily_042
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_042.jpg
# 按讚數: 1178
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0251
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_042)
# 第 25761 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/C-Eiw5LytMl/
# Post 編號: pt_motodaily_043
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_043.jpg
# 按讚數: 1932
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0411
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_043)
# 第 25762 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/C97VumcSD2T/
# Post 編號: pt_motodaily_044
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_044.jpg
# 按讚數: 2336
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0497
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_044)
# 第 25763 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/C9mLPIGy-a6/
# Post 編號: pt_motodaily_047
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_047.jpg
# 按讚數: 842
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0179
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_047)
# 第 25764 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/C9g6xx6SKuS/
# Post 編號: pt_motodaily_048
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\pt_motodaily\pt_motodaily_048.jpg
# 按讚數: 1449
# 粉絲數: 47000
# 互動率 (按讚數/粉絲數): 0.0308
# 貼文資料已成功插入資料庫 (Post ID: pt_motodaily_048)
# 第 25765 篇貼文
# Post Link: https://www.instagram.com/pt_motodaily/p/C9XqVgHSGeC/
# ...
# 第 26230 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/Ckmh4KaO-Ua/
# Post 編號: eddie_wang123_072
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_072.jpg
# 按讚數: 22000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0783
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_072)
# 第 26231 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CkXNzo2OPkC/
# Post 編號: eddie_wang123_073
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_073.jpg
# 按讚數: 15000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0534
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_073)
# 第 26232 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CkPX_DkOzcJ/
# Post 編號: eddie_wang123_074
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_074.jpg
# 按讚數: 20000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0712
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_074)
# 第 26233 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CkEiqLksmHU/
# Post 編號: eddie_wang123_075
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_075.jpg
# 按讚數: 25000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0890
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_075)
# 第 26234 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/Cj5F0rAI4kF/
# Post 編號: eddie_wang123_077
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_077.jpg
# 按讚數: 26000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0925
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_077)
# 第 26235 篇貼文是影片，跳過
# 第 26236 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CiAWiDxpdw-/
# Post 編號: eddie_wang123_080
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_080.jpg
# 按讚數: 28000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0996
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_080)
# 第 26237 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/ChZf_f6PqfQ/
# Post 編號: eddie_wang123_082
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_082.jpg
# 按讚數: 30000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.1068
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_082)
# 第 26238 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CfwSLeNv8eH/
# Post 編號: eddie_wang123_085
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_085.jpg
# 按讚數: 33000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.1174
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_085)
# 第 26239 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CfbD1vQOMsZ/
# Post 編號: eddie_wang123_086
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_086.jpg
# 按讚數: 20000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0712
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_086)
# 第 26240 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CfQnbwzM-4e/
# Post 編號: eddie_wang123_087
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_087.jpg
# 按讚數: 23000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0819
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_087)
# 第 26241 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CeI8vwgvo3s/
# Post 編號: eddie_wang123_090
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_090.jpg
# 按讚數: 29000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.1032
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_090)
# 第 26242 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CddYSNQvitz/
# Post 編號: eddie_wang123_092
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_092.jpg
# 按讚數: 39000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.1388
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_092)
# 第 26243 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CdTJLXgPtig/
# Post 編號: eddie_wang123_093
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_093.jpg
# 按讚數: 23000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0819
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_093)
# 第 26244 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CdGJfPFJTCm/
# Post 編號: eddie_wang123_094
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_094.jpg
# 按讚數: 23000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0819
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_094)
# 第 26245 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/Cc2gFWfvNNG/
# Post 編號: eddie_wang123_095
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_095.jpg
# 按讚數: 24000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0854
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_095)
# 第 26246 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CcmZ05bvB45/
# Post 編號: eddie_wang123_096
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_096.jpg
# 按讚數: 13000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.0463
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_096)
# 第 26247 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CcNT_3pPBYp/
# Post 編號: eddie_wang123_098
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_098.jpg
# 按讚數: 33000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.1174
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_098)
# 第 26248 篇貼文
# Post Link: https://www.instagram.com/eddie_wang123/p/CcDFGtQvaq4/
# Post 編號: eddie_wang123_100
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\eddie_wang123\eddie_wang123_100.jpg
# 按讚數: 34000
# 粉絲數: 281000
# 互動率 (按讚數/粉絲數): 0.1210
# 貼文資料已成功插入資料庫 (Post ID: eddie_wang123_100)
# 第 26249 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/Cttow5sS8O4/
# Post 編號: molly_chiang_001
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_001.jpg
# 按讚數: 12000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 9.5238
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_001)
# 第 26250 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/B3D781tnmWo/
# Post 編號: molly_chiang_003
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_003.jpg
# 按讚數: 27000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 21.4286
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_003)
# 第 26251 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DEpkJQ8SUz4/
# Post 編號: molly_chiang_005
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_005.jpg
# 按讚數: 12000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 9.5238
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_005)
# 第 26252 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DEckzSeyZAF/
# Post 編號: molly_chiang_008
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_008.jpg
# 按讚數: 6656
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 5.2825
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_008)
# 第 26253 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DEY98_FS7sZ/
# Post 編號: molly_chiang_009
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_009.jpg
# 按讚數: 6157
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 4.8865
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_009)
# 第 26254 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DEXiBJPSkw2/
# Post 編號: molly_chiang_010
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_010.jpg
# 按讚數: 5279
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 4.1897
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_010)
# 第 26255 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DET2H4YyoYq/
# Post 編號: molly_chiang_011
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_011.jpg
# 按讚數: 4726
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 3.7508
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_011)
# 第 26256 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDmg5PxuIjZ/
# Post 編號: molly_chiang_021
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_021.jpg
# 按讚數: 10000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 7.9365
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_021)
# 第 26257 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDkDUF5ut-b/
# Post 編號: molly_chiang_022
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_022.jpg
# 按讚數: 11000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 8.7302
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_022)
# 第 26258 篇貼文是影片，跳過
# 第 26259 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDe4nHmoylS/
# Post 編號: molly_chiang_025
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_025.jpg
# 按讚數: 11000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 8.7302
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_025)
# 第 26260 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDcM3xMOLRt/
# Post 編號: molly_chiang_029
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_029.jpg
# 按讚數: 13000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 10.3175
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_029)
# 第 26261 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDYkR6mOJij/
# Post 編號: molly_chiang_032
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_032.jpg
# 按讚數: 12000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 9.5238
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_032)
# 第 26262 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDXMsAZuV1U/
# Post 編號: molly_chiang_033
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_033.jpg
# 按讚數: 14000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 11.1111
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_033)
# 第 26263 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDTZ8UKOY1s/
# Post 編號: molly_chiang_037
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_037.jpg
# 按讚數: 26000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 20.6349
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_037)
# 第 26264 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDOKgCXS2BR/
# Post 編號: molly_chiang_039
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_039.jpg
# 按讚數: 7652
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 6.0730
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_039)
# 第 26265 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDNAm4Bybic/
# Post 編號: molly_chiang_040
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_040.jpg
# 按讚數: 3804
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 3.0190
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_040)
# 第 26266 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DDBHy5dSBwm/
# Post 編號: molly_chiang_042
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_042.jpg
# 按讚數: 7719
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 6.1262
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_042)
# 第 26267 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DC_xQnlSDkb/
# Post 編號: molly_chiang_044
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_044.jpg
# 按讚數: 4873
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 3.8675
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_044)
# 第 26268 篇貼文是影片，跳過
# 第 26269 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DC61cjGSBe5/
# Post 編號: molly_chiang_050
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_050.jpg
# 按讚數: 11000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 8.7302
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_050)
# 第 26270 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DC4Qm0TS2Pa/
# Post 編號: molly_chiang_051
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_051.jpg
# 按讚數: 19000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 15.0794
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_051)
# 第 26271 篇貼文是影片，跳過
# 第 26272 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DC1r0P0yGna/
# Post 編號: molly_chiang_053
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_053.jpg
# 按讚數: 17000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 13.4921
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_053)
# 第 26273 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DCwiQpPymR8/
# Post 編號: molly_chiang_054
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_054.jpg
# 按讚數: 9269
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 7.3563
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_054)
# 第 26274 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DCmPEm9SJ1m/
# Post 編號: molly_chiang_056
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_056.jpg
# 按讚數: 3363
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 2.6690
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_056)
# 第 26275 篇貼文是影片，跳過
# 第 26276 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DCegqg5yf5s/
# Post 編號: molly_chiang_059
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_059.jpg
# 按讚數: 9965
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 7.9087
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_059)
# 第 26277 篇貼文是影片，跳過
# 第 26278 篇貼文是影片，跳過
# 第 26279 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DCWyertyMRp/
# Post 編號: molly_chiang_062
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_062.jpg
# 按讚數: 14000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 11.1111
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_062)
# 第 26280 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DCUOvUpS2Lf/
# Post 編號: molly_chiang_063
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_063.jpg
# 按讚數: 22000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 17.4603
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_063)
# 第 26281 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DCRpJNKyxuD/
# Post 編號: molly_chiang_064
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_064.jpg
# 按讚數: 26000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 20.6349
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_064)
# 第 26282 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DCPDx1TyC1K/
# Post 編號: molly_chiang_065
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_065.jpg
# 按讚數: 15000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 11.9048
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_065)
# 第 26283 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DCCFTx3Sq62/
# Post 編號: molly_chiang_067
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_067.jpg
# 按讚數: 5073
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 4.0262
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_067)
# 第 26284 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DBq5yrGSsOp/
# Post 編號: molly_chiang_070
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_070.jpg
# 按讚數: 51000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 40.4762
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_070)
# 第 26285 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DBq2aOpSqyq/
# Post 編號: molly_chiang_071
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_071.jpg
# 按讚數: 35000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 27.7778
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_071)
# 第 26286 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DBY4N2UyI7m/
# Post 編號: molly_chiang_075
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_075.jpg
# 按讚數: 3527
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 2.7992
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_075)
# 第 26287 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DBVOuTCy7SC/
# Post 編號: molly_chiang_077
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_077.jpg
# 按讚數: 4250
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 3.3730
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_077)
# 第 26288 篇貼文是影片，跳過
# 第 26289 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DBPvq8MS2qS/
# Post 編號: molly_chiang_081
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_081.jpg
# 按讚數: 10000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 7.9365
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_081)
# 第 26290 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DBNgXqQuj9G/
# Post 編號: molly_chiang_082
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_082.jpg
# 按讚數: 10000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 7.9365
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_082)
# 第 26291 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DBMAQBuOy8u/
# Post 編號: molly_chiang_083
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_083.jpg
# 按讚數: 33000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 26.1905
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_083)
# 第 26292 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DBFx_rXyZbG/
# Post 編號: molly_chiang_091
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_091.jpg
# 按讚數: 4665
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 3.7024
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_091)
# 第 26293 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DA-DmYISVDy/
# Post 編號: molly_chiang_092
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_092.jpg
# 按讚數: 5470
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 4.3413
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_092)
# 第 26294 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DAyX8pGSKHA/
# Post 編號: molly_chiang_095
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_095.jpg
# 按讚數: 15000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 11.9048
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_095)
# 第 26295 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DAxL5fsyisv/
# Post 編號: molly_chiang_096
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_096.jpg
# 按讚數: 5793
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 4.5976
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_096)
# 第 26296 篇貼文
# Post Link: https://www.instagram.com/molly_chiang/p/DAtNkZ8SDqt/
# Post 編號: molly_chiang_098
# 圖片已成功儲存至 C:\Users\SHI\Desktop\KOL\ig_photos\molly_chiang\molly_chiang_098.jpg
# 按讚數: 10000
# 粉絲數: 1260
# 互動率 (按讚數/粉絲數): 7.9365
# 貼文資料已成功插入資料庫 (Post ID: molly_chiang_098)
# 🌙 已處理 700 篇貼文，休息 1.7 分鐘...
# 第 26297 篇貼文是影片，跳過
# 共處理 700 篇貼文
# []

# %% [markdown]
# IG 怎麼推播他的貼文
#
# 預測的模型要多嘗試幾個
